# %%
import pymongo
from spearmint.utils import compression
from spearmint.utils import functions
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from spearmint.tasks import input_space
sns.set()

# %%
opt_val = 0

# %% [markdown]
# ### Connecting MongoDB server

# %%
mongo_conn = pymongo.MongoClient('127.0.0.1',27017)
mongo_conn.list_database_names()
# Out:
# [u'admin', u'config', u'local', u'spearmint']

# %%
mongo_db = mongo_conn['spearmint']

# %%
mongo_db.list_collection_names()
# Out:
# [u'levy_2-68.recommendations',
#  u'levy_1-60.recommendations',
#  u'levyN13_1-71.start-time',
#  u'levy_2-43.jobs',
#  u'levy_4-38.jobs',
#  u'levyN13_1-73.start-time',
#  u'levyN13_1-82.start-time',
#  u'levy_1-74.recommendations',
#  u'levy_4-60.hypers',
#  u'levyN13_1-88.jobs',
#  u'levyN13_1-2.recommendations',
#  u'levy_2-22.start-time',
#  u'levy_2-42.jobs',
#  u'levyN13_1-14.jobs',
#  u'levy_2-85.hypers',
#  u'levy_2-17.jobs',
#  u'levy_1-3.hypers',
#  u'levyN13_1-36.jobs',
#  u'levyN13_1-14.hypers',
#  u'levyN13_1-88.hypers',
#  u'levy_1-56.recommendations',
#  u'levy_1-87.recommendations',
#  u'levy_1-91.hypers',
#  u'levy_4-55.hypers',
#  u'levy_2-90.hypers',
#  u'levy_4-50.start-time',
#  u'levy_4-36.recommendations',
#  u'levy_1-79.jobs',
#  u'levy_2-75.hypers',
#  u'levy_4-1.recommendations',
#  u'levyN13_1-42.start-time',
#  u'levy_1-59.jobs',
#  u'levy_2-93.start-time',
#  u'levyN13_1-68.jobs',
#  u'levyN13_1-50.recommendations',
#  u'levy_2-86.recommendations',
#  u'levy_2-74.jobs',
#  u'levy_2-54.recommendations',
#  u'levy_2-53.jobs',
#  u'levy_1-13.start-time',
#  u'levy_2-54.start-time',
#  u'levy_2-64.jobs',
#  u'levy_2-64.recommendations',
#  u'levy_1-80.start-time',
#  u'levy_2-35.recommendations',
#  u'levy_1-13.hypers',
#  u'levy_1-77.start-time',
#  u'levy_1-14.recommendations',
#  u'levy_4-31.start-time',
#  u'levy_1-78.recommendations',
#  u'levy_1-62.recommendations',
#  u'levy_2-1.start-time',
#  u'levy_1-97.jobs',
#  u'levy_2-65.jobs',
#  u'levy_4-26.start-time',
#  u'levy_1-99.jobs',
#  u'levy_1-64.start-time',
#  u'levy_2-94.start-time',
#  u'levy_2-77.start-time',
#  u'levy_1-12.start-time',
#  u'levy_1-67.recommendations',
#  u'levy_4-73.jobs',
#  u'levy_4-88.jobs',
#  u'levy_4-46.recommendations',
#  u'levy_4-96.hypers',
#  u'levy_1-6.recommendations',
#  u'levyN13_1-27.start-time',
#  u'levyN13_1-49.start-time',
#  u'levyN13_1-69.jobs',
#  u'levyN13_1-25.hypers',
#  u'levyN13_1-46.hypers',
#  u'levyN13_1-65.recommendations',
#  u'levy_4-58.recommendations',
#  u'levy_4-54.hypers',
#  u'levy_1-78.jobs',
#  u'levy_1-97.hypers',
#  u'levy_4-56.hypers',
#  u'levyN13_1-9.start-time',
#  u'levy_1-55.start-time',
#  u'levy_1-86.jobs',
#  u'levy_1-38.recommendations',
#  u'levy_4-43.start-time',
#  u'levy_2-45.hypers',
#  u'levy_4-83.start-time',
#  u'levyN13_1-37.recommendations',
#  u'levy_2-17.recommendations',
#  u'levy_4-6.start-time',
#  u'levy_2-46.start-time',
#  u'levy_1-91.jobs',
#  u'levy_1-69.hypers',
#  u'levy_2-37.jobs',
#  u'levy_1-2.start-time',
#  u'levy_2-95.jobs',
#  u'levy_2-12.recommendations',
#  u'levy_4-10.jobs',
#  u'levy_4-58.hypers',
#  u'levy_4-83.recommendations',
#  u'levyN13_1-87.hypers',
#  u'levy_1-69.jobs',
#  u'levy_4-45.jobs',
#  u'levy_1-31.jobs',
#  u'levy_1-77.jobs',
#  u'levy_1-34.jobs',
#  u'levy_4-23.start-time',
#  u'levy_4-13.jobs',
#  u'levy_4-49.jobs',
#  u'levy_4-68.jobs',
#  u'levy_2-32.start-time',
#  u'levy_2-74.hypers',
#  u'levy_1-2.jobs',
#  u'levy_2-75.jobs',
#  u'levy_1-32.jobs',
#  u'levy_1-94.start-time',
#  u'levy_4-30.recommendations',
#  u'levy_4-47.recommendations',
#  u'levy_1-64.recommendations',
#  u'levy_4-49.start-time',
#  u'levy_2-52.recommendations',
#  u'levy_4-41.start-time',
#  u'levyN13_1-17.jobs',
#  u'levy_2-75.start-time',
#  u'levy_1-96.start-time',
#  u'levy_1-43.jobs',
#  u'levy_4-35.recommendations',
#  u'levy_2-41.recommendations',
#  u'levyN13_1-4.hypers',
#  u'levy_2-29.start-time',
#  u'levy_1-83.start-time',
#  u'levy_1-93.jobs',
#  u'levy_1-81.recommendations',
#  u'levyN13_1-28.jobs',
#  u'levyN13_1-72.start-time',
#  u'levy_2-16.jobs',
#  u'levy_2-34.start-time',
#  u'levy_2-96.hypers',
#  u'levy_2-95.recommendations',
#  u'levy_1-29.hypers',
#  u'levy_4-67.start-time',
#  u'levyN13_1-51.jobs',
#  u'levyN13_1-13.recommendations',
#  u'levyN13_1-24.hypers',
#  u'levyN13_1-54.hypers',
#  u'levy_2-56.jobs',
#  u'levy_1-72.recommendations',
#  u'levy_1-61.recommendations',
#  u'levy_1-12.jobs',
#  u'levy_1-41.start-time',
#  u'levy_1-6.hypers',
#  u'levy_4-6.jobs',
#  u'levy_4-50.jobs',
#  u'levy_1-91.start-time',
#  u'levy_4-95.jobs',
#  u'levy_4-65.hypers',
#  u'levyN13_1-84.start-time',
#  u'levyN13_1-83.jobs',
#  u'levy_2-9.recommendations',
#  u'levy_1-71.hypers',
#  u'levy_4-53.hypers',
#  u'levy_2-19.hypers',
#  u'levy_4-61.hypers',
#  u'levy_2-20.hypers',
#  u'levyN13_1-70.recommendations',
#  u'levy_2-98.hypers',
#  u'levy_2-99.jobs',
#  u'levyN13_1-79.recommendations',
#  u'levy_1-15.jobs',
#  u'levy_2-41.hypers',
#  u'levy_4-92.jobs',
#  u'levy_1.recommendations',
#  u'levy_2-76.hypers',
#  u'levy_4-28.jobs',
#  u'levy_4-93.jobs',
#  u'levy_4-43.recommendations',
#  u'levyN13_1-61.hypers',
#  u'levyN13_1-97.hypers',
#  u'levyN13_1-43.start-time',
#  u'levyN13_1-38.hypers',
#  u'levy_1-14.start-time',
#  u'levy_1-31.recommendations',
#  u'levy_1-28.hypers',
#  u'levy_1-79.recommendations',
#  u'levy_4-96.jobs',
#  u'levyN13_1-61.start-time',
#  u'levyN13_1-34.hypers',
#  u'levy_1-1.hypers',
#  u'levyN13_1-52.hypers',
#  u'levyN13_1-55.recommendations',
#  u'levyN13_1-74.recommendations',
#  u'levyN13_1-29.jobs',
#  u'levyN13_1-79.start-time',
#  u'levy_4-28.recommendations',
#  u'levy_2-89.hypers',
#  u'levy_4-15.start-time',
#  u'levyN13_1-9.recommendations',
#  u'levy_2-63.jobs',
#  u'levyN13_1-86.jobs',
#  u'levy_4-38.hypers',
#  u'levy_2-13.jobs',
#  u'levy_2-89.jobs',
#  u'levy_4-81.hypers',
#  u'levy_4-90.hypers',
#  u'levy_1-4.start-time',
#  u'levy_2-79.hypers',
#  u'levy_4-31.jobs',
#  u'levy_2-28.recommendations',
#  u'levy_1-75.start-time',
#  u'levy_1-42.recommendations',
#  u'levy_1-11.recommendations',
#  u'levy_4-51.recommendations',
#  u'levy_1-57.recommendations',
#  u'levy_1-61.start-time',
#  u'levy_4-53.recommendations',
#  u'levy_2-31.jobs',
#  u'levy_4-40.jobs',
#  u'levy_4-43.jobs',
#  u'levy_4-27.recommendations',
#  u'levy_2-24.hypers',
#  u'levy_2-84.recommendations',
#  u'levy_2-25.start-time',
#  u'levy_1-98.start-time',
#  u'levy_4-36.jobs',
#  u'levy_4-84.hypers',
#  u'levy_4-7.hypers',
#  u'levy_4-66.recommendations',
#  u'levy_1-30.jobs',
#  u'levyN13_1-82.hypers',
#  u'levy_4-75.jobs',
#  u'levy_4-82.start-time',
#  u'levyN13_1-83.hypers',
#  u'levy_1-97.start-time',
#  u'levyN13_1-10.start-time',
#  u'levy_2-49.recommendations',
#  u'levy_2-8.start-time',
#  u'levy_2-53.recommendations',
#  u'levy_2-34.recommendations',
#  u'levy_1-58.recommendations',
#  u'levyN13_1-26.start-time',
#  u'levy_2-58.hypers',
#  u'levy_1-27.hypers',
#  u'levy_4-97.recommendations',
#  u'levyN13_1-28.hypers',
#  u'levy_2-27.recommendations',
#  u'levy_4-19.recommendations',
#  u'levy_4-12.hypers',
#  u'levy_2-4.hypers',
#  u'levy_2-81.recommendations',
#  u'levyN13_1-1.start-time',
#  u'levy_4-77.recommendations',
#  u'levyN13_1-39.hypers',
#  u'levy_1-80.jobs',
#  u'levyN13_1-51.recommendations',
#  u'levy_1-33.recommendations',
#  u'levyN13_1-20.start-time',
#  u'levy_1-65.hypers',
#  u'levy_1-58.hypers',
#  u'levy_4-5.start-time',
#  u'levyN13_1-92.jobs',
#  u'levy_2-89.start-time',
#  u'levy_2-55.recommendations',
#  u'levyN13_1-43.hypers',
#  u'levy_2-74.recommendations',
#  u'levy_1-51.jobs',
#  u'levy_2-10.hypers',
#  u'levyN13_1-13.start-time',
#  u'levy_2-19.start-time',
#  u'levy_2-34.jobs',
#  u'levy_2-55.start-time',
#  u'levy_2-43.hypers',
#  u'levyN13_1-0.recommendations',
#  u'levy_4-68.hypers',
#  u'levy_2-80.hypers',
#  u'levy_2-38.start-time',
#  u'levyN13_1-6.recommendations',
#  u'levyN13_1-56.recommendations',
#  u'levy_2-50.jobs',
#  u'levyN13_1-25.jobs',
#  u'levyN13_1-21.recommendations',
#  u'levyN13_1-35.hypers',
#  u'levy_4-28.start-time',
#  u'levy_1-50.start-time',
#  u'levy_2-0.hypers',
#  u'levy_1-46.hypers',
#  u'levyN13_1-73.jobs',
#  u'levy_2-32.jobs',
#  u'levy_1-70.jobs',
#  u'levyN13_1-42.recommendations',
#  u'levy_2-70.recommendations',
#  u'levy_4-50.hypers',
#  u'levy_2-45.recommendations',
#  u'levy_4-51.start-time',
#  u'levy_4-56.jobs',
#  u'levyN13_1-69.recommendations',
#  u'levy_2-84.jobs',
#  u'levy_2-48.hypers',
#  u'levy_1-46.jobs',
#  u'levyN13_1-24.jobs',
#  u'levy_2-26.jobs',
#  u'levy_4-86.recommendations',
#  u'levy_1-14.hypers',
#  u'levy_2-6.start-time',
#  u'levy_2-94.jobs',
#  u'levy_1-24.recommendations',
#  u'levy_1-23.start-time',
#  u'levy_4-82.hypers',
#  u'levy_4-98.hypers',
#  u'levy_2-14.jobs',
#  u'levy_1-61.hypers',
#  u'levy_2-21.start-time',
#  u'levy_2-39.start-time',
#  u'levyN13_1-11.recommendations',
#  u'levy_1-78.start-time',
#  u'levy_1-3.recommendations',
#  u'levy_2-1.jobs',
#  u'levy_2-90.jobs',
#  u'levy_1-88.hypers',
#  u'levy_1-52.jobs',
#  u'levyN13_1-23.start-time',
#  u'levyN13_1-1.jobs',
#  u'levy_1-9.jobs',
#  u'levy_2-42.hypers',
#  u'levyN13_1-7.hypers',
#  u'levy_2-50.hypers',
#  u'levy_4-24.jobs',
#  u'levyN13_1-3.hypers',
#  u'levy_1-47.hypers',
#  u'levyN13_1-20.hypers',
#  u'levy_1-90.jobs',
#  u'levy_1-96.hypers',
#  u'levy_1-28.start-time',
#  u'levy_1-93.recommendations',
#  u'levyN13_1-79.hypers',
#  u'levyN13_1-63.recommendations',
#  u'levyN13_1-67.recommendations',
#  u'levy_2-64.start-time',
#  u'levy_1-34.recommendations',
#  u'levy_2-16.hypers',
#  u'levy_2-62.recommendations',
#  u'levy_2-73.hypers',
#  u'levy_4-47.jobs',
#  u'levy_2-5.jobs',
#  u'levy_1-22.start-time',
#  u'levy_1-63.jobs',
#  u'levy_2-72.jobs',
#  u'levy_1-60.start-time',
#  u'levy_4-80.hypers',
#  u'levy_4-33.recommendations',
#  u'levy_1-49.hypers',
#  u'levy_4-63.jobs',
#  u'levyN13_1-45.start-time',
#  u'levy_1-59.start-time',
#  u'levy_2-47.start-time',
#  u'levy_2-73.recommendations',
#  u'levy_2-22.recommendations',
#  u'levy_1-8.recommendations',
#  u'levy_4-26.hypers',
#  u'levyN13_1-69.start-time',
#  u'levy_4-23.recommendations',
#  u'levy_4-44.jobs',
#  u'levy_1-30.recommendations',
#  u'levy_1-18.recommendations',
#  u'levy_4-42.start-time',
#  u'levy_4-1.start-time',
#  u'levyN13_1-22.start-time',
#  u'levy_4-2.start-time',
#  u'levyN13_1-5.recommendations',
#  u'levy_2-57.jobs',
#  u'levy_2-19.recommendations',
#  u'levy_1-21.start-time',
#  u'levy_4-89.recommendations',
#  u'levy_4-11.start-time',
#  u'levyN13_1-33.hypers',
#  u'levyN13_1-10.jobs',
#  u'levy_1-81.hypers',
#  u'levyN13_1-30.jobs',
#  u'levy_4-59.jobs',
#  u'levy_2-66.start-time',
#  u'levy_1-18.start-time',
#  u'levy_4-84.jobs',
#  u'levy_1-90.start-time',
#  u'levy_4-74.jobs',
#  u'levy_4-7.recommendations',
#  u'levyN13_1-15.start-time',
#  u'levyN13_1-34.recommendations',
#  u'levyN13_1-63.hypers',
#  u'levyN13_1-23.hypers',
#  u'levy_1-71.start-time',
#  u'levy_4-86.jobs',
#  u'levy_4-97.hypers',
#  u'levyN13_1-93.start-time',
#  u'levyN13_1-10.hypers',
#  u'levy_4-70.start-time',
#  u'levyN13_1-15.hypers',
#  u'levyN13_1-41.hypers',
#  u'levy_2-28.jobs',
#  u'levy_1-43.recommendations',
#  u'levyN13_1-27.jobs',
#  u'levy_1-20.start-time',
#  u'levy_4-92.start-time',
#  u'levyN13_1-96.hypers',
#  u'levy_2-65.hypers',
#  u'levyN13_1-32.hypers',
#  u'levy_1-61.jobs',
#  u'levy_1-51.hypers',
#  u'levyN13_1-4.start-time',
#  u'levyN13_1-24.start-time',
#  u'levyN13_1-33.recommendations',
#  u'levyN13_1-70.start-time',
#  u'levy_2-99.recommendations',
#  u'levy_4-79.jobs',
#  u'levyN13_1-80.recommendations',
#  u'levy_1-39.recommendations',
#  u'levy_1-84.hypers',
#  u'levy_2-2.recommendations',
#  u'levy_2-99.hypers',
#  u'levy_4-17.recommendations',
#  u'levyN13_1-42.jobs',
#  u'levyN13_1-5.hypers',
#  u'levyN13_1-25.recommendations',
#  u'levyN13_1-64.recommendations',
#  u'levy_2-76.jobs',
#  u'levy_2-47.recommendations',
#  u'levyN13_1-94.recommendations',
#  u'levy_4-19.hypers',
#  u'levy_4-10.start-time',
#  u'levyN13_1-8.start-time',
#  u'levyN13_1-18.jobs',
#  u'levy_2-94.recommendations',
#  u'levy_4-64.hypers',
#  u'levy_1-1.start-time',
#  u'levy_1-0.start-time',
#  u'levyN13_1-97.recommendations',
#  u'levy_2-24.start-time',
#  u'levy_1-32.start-time',
#  u'levy_4-29.jobs',
#  u'levy_2-46.jobs',
#  u'levy_4-57.recommendations',
#  u'levyN13_1-99.hypers',
#  u'levy_2-4.jobs',
#  u'levy_1-16.hypers',
#  u'levy_1-4.jobs',
#  u'levyN13_1-26.jobs',
#  u'levyN13_1-51.hypers',
#  u'levy_2-8.hypers',
#  u'levy_1-25.recommendations',
#  u'levy_2-60.start-time',
#  u'levy_1-64.hypers',
#  u'levy_1-24.jobs',
#  u'levy_4-44.hypers',
#  u'levy_4-92.recommendations',
#  u'levy_2-69.hypers',
#  u'levyN13_1-50.start-time',
#  u'levyN13_1-9.hypers',
#  u'levy_4-21.jobs',
#  u'levyN13_1-11.hypers',
#  u'levy_2-29.recommendations',
#  u'levy_4-84.start-time',
#  u'levy_2-18.hypers',
#  u'levy_2-40.recommendations',
#  u'levy_2-80.recommendations',
#  u'levy_2-47.hypers',
#  u'levy_2-91.recommendations',
#  u'levy_4-62.jobs',
#  u'levy_4-87.jobs',
#  u'levy_4-30.hypers',
#  u'levy_4-49.recommendations',
#  u'levyN13_1-29.start-time',
#  u'levyN13_1-66.hypers',
#  u'levy_2-16.start-time',
#  u'levy_1-62.start-time',
#  u'levy_2-82.jobs',
#  u'levy_4-34.start-time',
#  u'levy_4-12.start-time',
#  u'levy_2-71.recommendations',
#  u'levy_2-2.hypers',
#  u'levy_1-38.start-time',
#  u'levy_1-72.start-time',
#  u'levy_1-53.jobs',
#  u'levy_2-28.start-time',
#  u'levy_1-10.start-time',
#  u'levy_4-5.jobs',
#  u'levy_2-33.hypers',
#  u'levy_4-9.hypers',
#  u'levy_1-95.start-time',
#  u'levy_4-72.recommendations',
#  u'levy_2-8.recommendations',
#  u'levyN13_1-30.start-time',
#  u'levy_4-99.recommendations',
#  u'levy_2-4.start-time',
#  u'levy_2-74.start-time',
#  u'levy_2-61.hypers',
#  u'levy_1-83.hypers',
#  u'levy_2-59.start-time',
#  u'levy_4-71.jobs',
#  u'levyN13_1-71.jobs',
#  u'levyN13_1-2.hypers',
#  u'levyN13_1-3.recommendations',
#  u'levyN13_1-63.start-time',
#  u'levy_4-7.start-time',
#  u'levy_2-90.recommendations',
#  u'levy_1-95.recommendations',
#  u'levy_4-48.jobs',
#  u'levy_2-21.hypers',
#  u'levy_1-71.jobs',
#  u'levy_2-91.start-time',
#  u'levy_1-7.jobs',
#  u'levy_4-4.start-time',
#  u'levy_1-79.hypers',
#  u'levy_4-39.jobs',
#  u'levy_4-34.recommendations',
#  u'levy_1-64.jobs',
#  u'levy_2-78.jobs',
#  u'levy_1-56.start-time',
#  u'levy_2-21.recommendations',
#  u'levy_1-77.recommendations',
#  u'levy_1-2.hypers',
#  u'levy_4-19.start-time',
#  u'levy_4-72.hypers',
#  u'levy_4-88.recommendations',
#  u'levy_2-82.hypers',
#  u'levyN13_1-33.jobs',
#  u'levy_1-30.start-time',
#  u'levy_1-32.recommendations',
#  u'levyN13_1-34.jobs',
#  u'levyN13_1-22.hypers',
#  u'levy_1-33.start-time',
#  u'levy_2-4.recommendations',
#  u'levy_2-71.start-time',
#  u'levy_1-5.jobs',
#  u'levyN13_1-68.recommendations',
#  u'levy_1-41.jobs',
#  u'levy_2-18.start-time',
#  u'levyN13_1-5.jobs',
#  u'levy_1-69.recommendations',
#  u'levy_4-9.jobs',
#  u'levyN13_1-43.recommendations',
#  u'levy_4-33.hypers',
#  u'levy_2-24.jobs',
#  u'levy_4-22.recommendations',
#  u'levy_4-49.hypers',
#  u'levyN13_1-74.start-time',
#  u'levy_2-26.hypers',
#  u'levy_1-27.jobs',
#  u'levy_1-58.start-time',
#  u'levy_1-85.start-time',
#  u'levy_1-46.recommendations',
#  u'levy_4-82.jobs',
#  u'levy_4-41.hypers',
#  u'levyN13_1-91.start-time',
#  u'levyN13_1-48.jobs',
#  u'levy_4-23.jobs',
#  u'levy_2-27.start-time',
#  u'levy_2-78.start-time',
#  u'levy_4-99.start-time',
#  u'levy_4-16.hypers',
#  u'levy_1-6.start-time',
#  u'levy_1-35.recommendations',
#  u'levyN13_1-35.jobs',
#  u'levyN13_1-49.hypers',
#  u'levyN13_1-70.hypers',
#  u'levy_4-14.hypers',
#  u'levyN13_1-17.recommendations',
#  u'levyN13_1-78.recommendations',
#  u'levy_1-79.start-time',
#  u'levy_4-27.jobs',
#  u'levyN13_1-39.jobs',
#  u'levy_2-93.jobs',
#  u'levy_2-7.start-time',
#  u'levy_2-59.hypers',
#  u'levy_1-37.jobs',
#  u'levy_1-42.jobs',
#  u'levy_1-82.jobs',
#  u'levy_4-74.hypers',
#  u'levyN13_1-90.jobs',
#  u'levyN13_1-95.recommendations',
#  u'levy_2-66.recommendations',
#  u'levy_2-18.recommendations',
#  u'levy_2-36.recommendations',
#  u'levyN13_1-90.hypers',
#  u'levy_2-37.hypers',
#  u'levy_2-66.hypers',
#  u'levy_4-58.jobs',
#  u'levy_2-73.start-time',
#  u'levy_2-80.jobs',
#  u'levy_1-30.hypers',
#  u'levy_1-21.recommendations',
#  u'levy_1-85.recommendations',
#  u'levy_4-94.start-time',
#  u'levy_4-21.hypers',
#  u'levy_4-16.recommendations',
#  u'levy_4-87.hypers',
#  u'levy_4-92.hypers',
#  u'levyN13_1-62.hypers',
#  u'levyN13_1-79.jobs',
#  u'levy_1-13.recommendations',
#  u'levy_1-99.recommendations',
#  u'levy_4-69.recommendations',
#  u'levy_2-83.start-time',
#  u'levyN13_1-46.jobs',
#  u'levy_4-77.start-time',
#  u'levy_2-96.start-time',
#  u'levy_4-98.start-time',
#  u'levy_2-44.start-time',
#  u'levy_2-98.recommendations',
#  u'levy_4-43.hypers',
#  u'levy_4-68.recommendations',
#  u'levyN13_1-91.jobs',
#  u'levy_2-88.jobs',
#  u'levy_1-48.start-time',
#  u'levy_2-72.recommendations',
#  u'levyN13_1-92.recommendations',
#  u'levy_1-29.jobs',
#  u'levy_1-93.start-time',
#  u'levy_1-56.hypers',
#  u'levy_2-3.recommendations',
#  u'levy_4-31.hypers',
#  u'levy_4-91.hypers',
#  u'levy_2-83.jobs',
#  u'levyN13_1-24.recommendations',
#  u'levy_2-71.hypers',
#  u'levyN13_1-18.start-time',
#  u'levyN13_1-53.hypers',
#  u'levy_4-66.start-time',
#  u'levy_4-91.recommendations',
#  u'levyN13_1-11.start-time',
#  u'levyN13_1-84.recommendations',
#  u'levy_1-6.jobs',
#  u'levy_2-20.start-time',
#  u'levy_1-75.hypers',
#  u'levy_1-53.hypers',
#  u'levy_4-62.start-time',
#  u'levy_4-29.recommendations',
#  u'levy_1-45.hypers',
#  u'levy_2-17.start-time',
#  u'levy_1-72.jobs',
#  u'levy_4-4.jobs',
#  u'levyN13_1-66.jobs',
#  u'levy_2-83.hypers',
#  u'levy_2-60.jobs',
#  u'levy_4-8.start-time',
#  u'levy_1-54.hypers',
#  u'levy_1-37.hypers',
#  u'levy_1-35.start-time',
#  u'levy_4-37.hypers',
#  u'levy_1-27.start-time',
#  u'levy_1-8.jobs',
#  u'levy_2-30.jobs',
#  u'levy_4-37.recommendations',
#  u'levy_1-26.hypers',
#  u'levy_4-79.start-time',
#  u'levy_4-76.hypers',
#  u'levy_4-63.recommendations',
#  u'levy_2-39.jobs',
#  u'levy_4-54.recommendations',
#  u'levy_1-47.jobs',
#  u'levyN13_1-31.hypers',
#  u'levy_2-16.recommendations',
#  u'levy_1-26.recommendations',
#  u'levy_1-21.hypers',
#  u'levy_2-87.start-time',
#  u'levy_4-95.hypers',
#  u'levy_4-21.recommendations',
#  u'levy_4-65.recommendations',
#  u'levyN13_1-11.jobs',
#  u'levy_4-61.recommendations',
#  u'levyN13_1-80.start-time',
#  u'levy_4-82.recommendations',
#  u'levy_4-70.jobs',
#  u'levyN13_1-77.jobs',
#  u'levyN13_1-75.recommendations',
#  u'levy_2-60.hypers',
#  u'levy_2-51.recommendations',
#  u'levy_1-98.hypers',
#  u'levy_1-76.recommendations',
#  u'levy_4-75.hypers',
#  u'levy_4-31.recommendations',
#  u'levy_4-99.hypers',
#  u'levy_4-99.jobs',
#  u'levy_4-51.jobs',
#  u'levyN13_1-35.start-time',
#  u'levy_2-26.recommendations',
#  u'levy_1-19.recommendations',
#  u'levy_2-57.recommendations',
#  u'levyN13_1-64.start-time',
#  u'levyN13_1-69.hypers',
#  u'levy_2-9.jobs',
#  u'levy_1-41.recommendations',
#  u'levy_4-20.start-time',
#  u'levyN13_1-30.recommendations',
#  u'levy_1-13.jobs',
#  u'levy_4-77.jobs',
#  u'levy_2-84.hypers',
#  u'levy_2-36.start-time',
#  u'levy_1-9.hypers',
#  u'levy_2-70.jobs',
#  u'levy_4-65.jobs',
#  u'levy_1-93.hypers',
#  u'levy_4-94.recommendations',
#  u'levy_4-42.hypers',
#  u'levy_1-25.jobs',
#  u'levy_2-51.hypers',
#  u'levy_2-14.recommendations',
#  u'levyN13_1-31.jobs',
#  u'levy_1-66.recommendations',
#  u'levy_4-24.recommendations',
#  u'levy_1-42.hypers',
#  u'levy_2-84.start-time',
#  u'levy_1-47.recommendations',
#  u'levy_4-22.hypers',
#  u'levy_4-3.hypers',
#  u'levy_2-65.recommendations',
#  u'levyN13_1-41.jobs',
#  u'levyN13_1-18.recommendations',
#  u'levyN13_1-81.hypers',
#  u'levy_1-18.jobs',
#  u'levyN13_1-15.recommendations',
#  u'levyN13_1-4.recommendations',
#  u'levy_1-21.jobs',
#  u'levyN13_1-84.hypers',
#  u'levy_4-6.hypers',
#  u'levy_4-48.hypers',
#  u'levyN13_1-58.start-time',
#  u'levy_2-7.hypers',
#  u'levy_1-11.hypers',
#  u'levy_4-3.start-time',
#  u'levy_4-25.jobs',
#  u'levy_1-0.recommendations',
#  u'levy_1-55.hypers',
#  u'levy_2-63.recommendations',
#  u'levy_4-33.start-time',
#  u'levy_4-98.recommendations',
#  u'levy_4-40.start-time',
#  u'levy_2-26.start-time',
#  u'levy_4-65.start-time',
#  u'levy_4-69.start-time',
#  u'levy_1-96.recommendations',
#  u'levy_4-66.jobs',
#  u'levy_4-80.jobs',
#  u'levyN13_1-66.start-time',
#  u'levyN13_1-74.hypers',
#  u'levyN13_1-38.start-time',
#  u'levy_1-53.recommendations',
#  u'levy_4-18.start-time',
#  u'levyN13_1-36.recommendations',
#  u'levy_4-52.recommendations',
#  u'levy_1-16.jobs',
#  u'levy_1-99.hypers',
#  u'levyN13_1-90.start-time',
#  u'levyN13_1-38.recommendations',
#  u'levy_2-9.hypers',
#  u'levy_1-37.start-time',
#  u'levyN13_1-8.recommendations',
#  u'levyN13_1-93.hypers',
#  u'levyN13_1-81.recommendations',
#  u'levy_2-58.jobs',
#  u'levyN13_1-74.jobs',
#  u'levyN13_1-55.start-time',
#  u'levyN13_1-96.jobs',
#  u'levyN13_1-95.jobs',
#  u'levy_1-65.jobs',
#  u'levy_2-30.hypers',
#  u'levyN13_1-53.jobs',
#  u'levyN13_1-54.recommendations',
#  u'levy_4-95.start-time',
#  u'levyN13_1-71.hypers',
#  u'levy_2-49.hypers',
#  u'levyN13_1-52.start-time',
#  u'levyN13_1-73.hypers',
#  u'levy_1-76.start-time',
#  u'levy_4-5.hypers',
#  u'levyN13_1-27.hypers',
#  u'levy_2-32.hypers',
#  u'levy_4-75.recommendations',
#  u'levy_2-10.start-time',
#  u'levy_2-87.jobs',
#  u'levy_4-34.jobs',
#  u'levyN13_1-28.start-time',
#  u'levy_2-62.start-time',
#  u'levy_1-67.hypers',
#  u'levy_1-92.recommendations',
#  u'levy_4-81.jobs',
#  u'levy_4-11.recommendations',
#  u'levy_1.jobs',
#  u'levy_2-36.hypers',
#  u'levy_2-73.jobs',
#  u'levyN13_1-44.start-time',
#  u'levy_2-92.start-time',
#  u'levyN13_1-92.start-time',
#  u'levyN13_1-8.hypers',
#  u'levy_4-78.hypers',
#  u'levy_2-40.start-time',
#  u'levy_2-57.start-time',
#  u'levy_2-22.hypers',
#  u'levy_2-43.recommendations',
#  u'levy_1-12.recommendations',
#  u'levy_4-77.hypers',
#  u'levy_1-39.hypers',
#  u'levyN13_1-56.start-time',
#  u'levy_4-50.recommendations',
#  u'levy_2-60.recommendations',
#  u'levyN13_1-38.jobs',
#  u'levyN13_1-89.hypers',
#  u'levyN13_1-70.jobs',
#  u'levyN13_1-21.jobs',
#  u'levy_2-92.recommendations',
#  u'levy_2-7.jobs',
#  u'levy_1-84.jobs',
#  u'levy_4-13.start-time',
#  u'levy_2-21.jobs',
#  u'levy_1-45.recommendations',
#  u'levy_1-44.jobs',
#  u'levy_1-49.start-time',
#  u'levy_2-23.jobs',
#  u'levy_1-54.recommendations',
#  u'levy_4-60.jobs',
#  u'levy_4-85.hypers',
#  u'levy_4-25.recommendations',
#  u'levyN13_1-47.start-time',
#  u'levyN13_1-26.hypers',
#  u'levy_2-99.start-time',
#  u'levyN13_1-60.hypers',
#  u'levyN13_1-19.start-time',
#  u'levy_1-82.recommendations',
#  u'levyN13_1-14.start-time',
#  u'levyN13_1-85.start-time',
#  u'levyN13_1-76.jobs',
#  u'levy_2-48.start-time',
#  u'levy_2-95.hypers',
#  u'levy_1-1.jobs',
#  u'levy_4-3.jobs',
#  u'levy_4-68.start-time',
#  u'levy_1-73.jobs',
#  u'levy_4-8.jobs',
#  u'levyN13_1-64.jobs',
#  u'levy_2-85.start-time',
#  u'levyN13_1-15.jobs',
#  u'levy_2-10.jobs',
#  u'levy_4-41.jobs',
#  u'levy_4-42.jobs',
#  u'levy_4-98.jobs',
#  u'levy_4-93.start-time',
#  u'levyN13_1-89.jobs',
#  u'levyN13_1-94.jobs',
#  u'levy_4-7.jobs',
#  u'levy_4-64.jobs',
#  u'levyN13_1-50.hypers',
#  u'levyN13_1-64.hypers',
#  u'levy_1-62.jobs',
#  u'levy_4-55.recommendations',
#  u'levy_4-40.hypers',
#  u'levy_4-9.start-time',
#  u'levy_1-92.jobs',
#  u'levy_4-67.hypers',
#  u'levyN13_1-59.recommendations',
#  u'levy_1-88.recommendations',
#  u'levy_2-1.hypers',
#  u'levy_4-15.hypers',
#  u'levy_4-96.recommendations',
#  u'levyN13_1-47.recommendations',
#  u'levyN13_1-52.recommendations',
#  u'levyN13_1-27.recommendations',
#  u'levyN13_1-80.jobs',
#  u'levy_4-17.start-time',
#  u'levy_4-25.start-time',
#  u'levy_1-83.recommendations',
#  u'levy_4-22.start-time',
#  u'levy_4-12.recommendations',
#  u'levy_1-40.jobs',
#  u'levy_4-89.hypers',
#  u'levy_2-15.recommendations',
#  u'levy_4-59.hypers',
#  u'levy_2-56.recommendations',
#  u'levy_4-18.jobs',
#  u'levyN13_1-45.jobs',
#  u'levy_2-10.recommendations',
#  u'levy_2-62.hypers',
#  u'levyN13_1-77.start-time',
#  u'levyN13_1-47.jobs',
#  u'levy_2-40.jobs',
#  u'levyN13_1-44.recommendations',
#  u'levy_4-45.recommendations',
#  u'levy_2-27.jobs',
#  u'levy_4-14.recommendations',
#  u'levy_2-5.recommendations',
#  u'levyN13_1-78.start-time',
#  u'levy_4-0.recommendations',
#  u'levy_4-21.start-time',
#  u'levy_2-82.recommendations',
#  u'levy_2-44.recommendations',
#  u'levy_1.start-time',
#  u'levy_1-3.jobs',
#  u'levy_2-75.recommendations',
#  u'levy_1-31.start-time',
#  u'levyN13_1-48.start-time',
#  u'levyN13_1-26.recommendations',
#  u'levy_2-47.jobs',
#  u'levyN13_1-0.jobs',
#  u'levyN13_1-96.start-time',
#  u'levy_4-63.hypers',
#  u'levyN13_1-9.jobs',
#  u'levyN13_1-18.hypers',
#  u'levy_1-10.hypers',
#  u'levy_2-89.recommendations',
#  u'levy_2-67.hypers',
#  u'levy_4-83.hypers',
#  u'levy_1-87.hypers',
#  u'levy_4-69.jobs',
#  u'levyN13_1-22.jobs',
#  u'levyN13_1-97.start-time',
#  u'levy_2-70.hypers',
#  u'levyN13_1-55.hypers',
#  u'levyN13_1-40.jobs',
#  u'levy_1-80.recommendations',
#  u'levyN13_1-47.hypers',
#  u'levy_1-75.jobs',
#  u'levy_1-15.start-time',
#  u'levy_4-52.start-time',
#  u'levy_4-56.start-time',
#  u'levy_4-13.recommendations',
#  u'levyN13_1-2.start-time',
#  u'levy_1-23.hypers',
#  u'levyN13_1-62.recommendations',
#  u'levy_4-54.start-time',
#  u'levy_1-28.recommendations',
#  u'levy_2-53.hypers',
#  u'levy_1-52.hypers',
#  u'levy_1-86.hypers',
#  u'levy_1-35.hypers',
#  u'levy_1-16.recommendations',
#  u'levy_4-60.recommendations',
#  u'levyN13_1-67.start-time',
#  u'levy_1-24.start-time',
#  u'levy_1-72.hypers',
#  u'levy_1-5.hypers',
#  u'levyN13_1-3.start-time',
#  u'levy_4-20.jobs',
#  u'levy_2-38.recommendations',
#  u'levyN13_1-19.recommendations',
#  u'levyN13_1-1.hypers',
#  u'levy_4-83.jobs',
#  u'levyN13_1-58.jobs',
#  u'levyN13_1-78.jobs',
#  u'levyN13_1-28.recommendations',
#  u'levyN13_1-93.recommendations',
#  u'levyN13_1-77.hypers',
#  u'levyN13_1-6.start-time',
#  u'levy_2-97.start-time',
#  u'levy_4-73.hypers',
#  u'levy_2-69.start-time',
#  u'levy_2-86.start-time',
#  u'levy_2-96.jobs',
#  u'levy_2-39.recommendations',
#  u'levy_1-87.jobs',
#  u'levy_1-23.recommendations',
#  u'levy_1-75.recommendations',
#  u'levy_2-6.jobs',
#  u'levy_1-89.recommendations',
#  u'levy_1-54.jobs',
#  u'levy_4-86.start-time',
#  u'levy_4-10.hypers',
#  u'levy_2-20.recommendations',
#  u'levy_4-76.recommendations',
#  u'levy_2-85.jobs',
#  u'levy_4-35.jobs',
#  u'levyN13_1-75.jobs',
#  u'levyN13_1-85.recommendations',
#  u'levyN13_1-42.hypers',
#  u'levy_2-9.start-time',
#  u'levy_2-55.hypers',
#  u'levyN13_1-54.start-time',
#  u'levy_2-81.hypers',
#  u'levy_4-51.hypers',
#  u'levy_1-94.recommendations',
#  u'levy_2-81.start-time',
#  u'levy_4-48.recommendations',
#  u'levy_1-38.hypers',
#  u'levy_1-65.start-time',
#  u'levy_1-36.recommendations',
#  u'levy_1-97.recommendations',
#  u'levy_4-17.jobs',
#  u'levyN13_1-23.jobs',
#  u'levyN13_1-1.recommendations',
#  u'levy_4-95.recommendations',
#  u'levy_2-29.jobs',
#  u'levy_4-80.recommendations',
#  u'levy_1-57.jobs',
#  u'levy_1-58.jobs',
#  u'levy_4-85.recommendations',
#  u'levy_4-15.recommendations',
#  u'levy_2-12.hypers',
#  u'levy_4-36.start-time',
#  u'levy_4-2.jobs',
#  u'levy_2-68.jobs',
#  u'levy_4-36.hypers',
#  u'levy_4-93.hypers',
#  u'levy_4-24.start-time',
#  u'levyN13_1-37.start-time',
#  u'levy_2-78.recommendations',
#  u'levy_2-15.start-time',
#  u'levy_4-30.jobs',
#  u'levy_4-57.jobs',
#  ...]

# %% [markdown]
# ### Loading document from database

# %%
jobs1_exp = []
jobs2_exp = []
jobs3_exp = []
#jobs4_exp = []

recomm1_exp = []
recomm2_exp = []
recomm3_exp = []
#recomm4_exp = []

for i in range(100):
    jobs1_exp.append(mongo_db["levyN13_1-%d.jobs"%i])
    jobs2_exp.append(mongo_db["levyN13_2-%d.jobs"%i])
    jobs3_exp.append(mongo_db["levyN13_3-%d.jobs"%i])
    #jobs4_exp.append(mongo_db["levyN13_4-%d.jobs"%i])
    
    recomm1_exp.append(mongo_db["levyN13_1-%d.recommendations"%i])
    recomm2_exp.append(mongo_db["levyN13_2-%d.recommendations"%i])
    recomm3_exp.append(mongo_db["levyN13_3-%d.recommendations"%i])
    #recomm4_exp.append(mongo_db["levyN13_4-%d.recommendations"%i])

# %%
levyN13_1_objs = functions.get_objective(recomm1_exp)
levyN13_2_objs = functions.get_objective(recomm2_exp)
levyN13_3_objs = functions.get_objective(recomm3_exp)
#levyN13_4_objs = functions.get_objective(recomm4_exp)

# %%
levyN13_1_objs = np.average(levyN13_1_objs, axis = 0)
levyN13_2_objs = np.average(levyN13_2_objs, axis = 0)
#levyN13_4_objs = np.average(levyN13_4_objs, axis = 0)
levyN13_3_objs = np.average(levyN13_3_objs, axis = 0)

# %%
plt.plot(levyN13_1_objs[:-2], label = 'Mk=5, Mj=5')
plt.plot(levyN13_2_objs[:-2], label = 'Mk=10, Mj=1')
plt.plot(levyN13_3_objs[:-2], label = 'Mk=1, Mj=10')
plt.ylim(-2,30)
plt.xlim(-2,15)
plt.legend()

# %% [markdown]
# ### Getting immediate Regre IR measure

# %%
def levy_N13(x1,x2):
	a = np.sin(3*np.pi*x1)**2
	b = ((x1-1)**2)*(1+(np.sin(3*np.pi*x2)**2))
	c = ((x2-1)**2)*(1+(np.sin(2*np.pi*x2)**2))

	result = a + b + c

	return result

# %%
def log_ir(input_list):
    return np.log10(np.abs(opt_val - levy_N13(*input_list)))

# %%
def get_irs_whole_exp(locs_exp):
    irs_exp = []
    for exp_num in range(len(locs_exp)):
        irs_iter = []
        locs_cur_exp = locs_exp[exp_num]
        
        for locs in locs_cur_exp:
            irs_iter.append(log_ir(locs))
            
        irs_exp.append(irs_iter)
        
    return irs_exp

# %%
def get_avg_irs(irs_exp):
    avg_irs = []
    for iter_num in range(len(irs_exp[0])):
        cur_iter_irs = []
        for exp_num in range(len(irs_exp)):
            cur_iter_irs.append(irs_exp[exp_num][iter_num])
            
        avg_irs.append(np.average(cur_iter_irs))
        
    return avg_irs

# %%
def get_avg_irs2(irs_exp):
    avg_irs = []
    for iter_num in range(50):
        cur_iter_irs = []
        for exp_num in range(len(irs_exp)):
            cur_iter_irs.append(irs_exp[exp_num][iter_num])
            
        avg_irs.append(np.average(cur_iter_irs))
        
    return avg_irs

# %%
def get_median_irs(irs_exp):
    median_irs = []
    for iter_num in range(len(irs_exp[0])):
        cur_iter_irs = []
        for exp_num in range(len(irs_exp)):
            cur_iter_irs.append(irs_exp[exp_num][iter_num])
        
        median_irs.append(np.median(cur_iter_irs))
        
    return median_irs

# %%
def get_median_irs2(irs_exp):
    median_irs = []
    for iter_num in range(50):
        cur_iter_irs = []
        for exp_num in range(len(irs_exp)):
            cur_iter_irs.append(irs_exp[exp_num][iter_num])
        
        median_irs.append(np.median(cur_iter_irs))
        
    return median_irs

# %%
locs1_exp = functions.get_recomm(recomm1_exp)
locs2_exp = functions.get_recomm(recomm2_exp)
locs3_exp = functions.get_recomm(recomm3_exp)
#locs4_exp = functions.get_recomm(recomm4_exp)

# %%
irs1_exp = get_irs_whole_exp(locs1_exp)
irs2_exp = get_irs_whole_exp(locs2_exp)
irs3_exp = get_irs_whole_exp(locs3_exp)
#irs4_exp = get_irs_whole_exp(locs4_exp)

# %%
irs1_median = get_median_irs(irs1_exp)
irs2_median = get_median_irs(irs2_exp)
irs3_median = get_median_irs(irs3_exp)
#irs4_median = get_median_irs(irs4_exp)

# %%
irs1_avg = get_avg_irs(irs1_exp)
irs2_avg = get_avg_irs(irs2_exp)
irs3_avg = get_avg_irs(irs3_exp)
#irs4_avg = get_avg_irs(irs4_exp)

# %%
plt.plot(irs1_median,label='Mk=5, Mj=5')
plt.plot(irs2_median,label='Mk=10, Mj=1')
plt.plot(irs3_median,label='Mk=1, Mj=10')
#plt.plot(irs4_median,label='Mk=1, Mj=10')
plt.legend()

# %%
plt.plot(irs1_avg,label='Mk=5, Mj=5')
plt.plot(irs2_avg,label='Mk=10, Mj=1')
plt.plot(irs3_avg,label='Mk=1, Mj=10')
#plt.plot(irs4_avg,label='Mk=1, Mj=10')
plt.legend()
