# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import os

# %%
file_path = os.getcwd()

# %%
file_path = file_path + "\\hartmann_var_check_200"

# %%
for i in range(5,34):
    df = pd.read_excel("%s\\info_%d.xlsx"%(file_path,i))
    
    plt.figure(figsize=(14,5))
    plt.plot(df['Avg'],label='First')
    plt.plot(df['Avg.1'], label='Second')
    
    
    plt.ylim(ymin=0,ymax=0.3)
    plt.legend()
    plt.title("%d iter acuqisition values"%i)
    plt.show()
