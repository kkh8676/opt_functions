# %%
import pymongo
from spearmint.utils import compression
from spearmint.utils import functions
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from spearmint.tasks import input_space
sns.set()

# %%
opt_val = 0

# %% [markdown]
# ### Connecting MongoDB server

# %%
mongo_conn = pymongo.MongoClient('127.0.0.1',27017)
mongo_conn.list_database_names()
# Out:
# [u'admin', u'config', u'local', u'spearmint']

# %%
mongo_db = mongo_conn['spearmint']

# %% [markdown]
# ### Loading document from database

# %%
jobs1_exp = []
jobs2_exp = []
jobs3_exp = []
jobs4_exp = []
jobs5_exp = []
jobs6_exp = []
jobs7_exp = []
jobs8_exp = []
jobs9_exp = []
jobs10_exp = []
jobs11_exp = []
jobs12_exp = []
jobs_no_acq_opt_exp = []
jobs_no_acq_opt_2_exp = []
jobs_no_initial_exp = []
jobs_no_initial_exp_2 = []

recomm1_exp = []
recomm2_exp = []
recomm3_exp = []
recomm4_exp = []
recomm5_exp = []
recomm6_exp = []
recomm7_exp = []
recomm8_exp = []
recomm9_exp = []
recomm10_exp = []
recomm11_exp = []
recomm12_exp = []
recomm_no_acq_opt_exp = []
recomm_no_acq_opt_2_exp = []
recomm_no_initial_exp = []
recomm_no_initial_exp_2 = []

for i in range(100):
    jobs1_exp.append(mongo_db["levy_1-%d.jobs"%i])
    jobs2_exp.append(mongo_db["levy_2-%d.jobs"%i])
    #jobs3_exp.append(mongo_db["levy_3-%d.jobs"%i])
    jobs4_exp.append(mongo_db["levy_4-%d.jobs"%i])
    jobs5_exp.append(mongo_db["levy_5-%d.jobs"%i])
    jobs6_exp.append(mongo_db["levy_6-%d.jobs"%i])
    jobs7_exp.append(mongo_db["levy_7-%d.jobs"%i])
    jobs8_exp.append(mongo_db["levy_8-%d.jobs"%i])
    jobs9_exp.append(mongo_db["levy_9-%d.jobs"%i])
    jobs10_exp.append(mongo_db["levy_10-%d.jobs"%i])
    #jobs11_exp.append(mongo_db["levy_11_KN-%d.jobs"%i])
    jobs12_exp.append(mongo_db["levy_12-%d.jobs"%i])
    jobs_no_acq_opt_exp.append(mongo_db["levy_no_acq_opt-%d.jobs"%i])
    jobs_no_acq_opt_2_exp.append(mongo_db["levy_no_acq_opt_2-%d.jobs"%i])
    jobs_no_initial_exp.append(mongo_db["levy_no_initial-%d.jobs"%i])
    jobs_no_initial_exp_2.append(mongo_db["levy_no_initial_2-%d.jobs"%i])
    
    recomm1_exp.append(mongo_db["levy_1-%d.recommendations"%i])
    recomm2_exp.append(mongo_db["levy_2-%d.recommendations"%i])
    #recomm3_exp.append(mongo_db["levy_3-%d.recommendations"%i])
    recomm4_exp.append(mongo_db["levy_4-%d.recommendations"%i])
    recomm5_exp.append(mongo_db["levy_5-%d.recommendations"%i])
    recomm6_exp.append(mongo_db["levy_6-%d.recommendations"%i])
    recomm7_exp.append(mongo_db["levy_7-%d.recommendations"%i])
    recomm7_exp.append(mongo_db["levy_7-%d.recommendations"%i])
    recomm8_exp.append(mongo_db["levy_8-%d.recommendations"%i])
    recomm9_exp.append(mongo_db["levy_9-%d.recommendations"%i])
    recomm10_exp.append(mongo_db["levy_10-%d.recommendations"%i])
    #recomm11_exp.append(mongo_db["levy_11_KN-%d.recommendations"%i])
    recomm12_exp.append(mongo_db["levy_12-%d.recommendations"%i])
    recomm_no_initial_exp.append(mongo_db["levy_no_initial-%d.recommendations"%i])
    recomm_no_initial_exp_2.append(mongo_db["levy_no_initial_2-%d.recommendations"%i])
    recomm_no_acq_opt_exp.append(mongo_db["levy_no_acq_opt-%d.recommendations"%i])
    recomm_no_acq_opt_2_exp.append(mongo_db["levy_no_acq_opt_2-%d.recommendations"%i])

# %% [markdown]
# ### For 25 version

# %%
jobs2_exp_25 = []
recomm2_exp_25 = []

for i in range(25):
    jobs2_exp_25.append(mongo_db["levy_2-%d.jobs"%i])
    
    recomm2_exp_25.append(mongo_db["levy_2-%d.recommendations"%i])

# %%
jobsKN_exp = []
jobsKN2_exp = []
jobsKN3_exp = []
jobsKN4_exp = []
jobsKN5_exp = []

recommKN_exp = []
recommKN2_exp = []
recommKN3_exp = []
recommKN4_exp = []
recommKN5_exp = []

for i in range(50):
    jobsKN_exp.append(mongo_db["levy_1_KN-%d.jobs"%i])
    jobsKN2_exp.append(mongo_db["levy_2_KN-%d.jobs"%i])
    jobsKN3_exp.append(mongo_db["levy_3_KN-%d.jobs"%i])
    #jobsKN4_exp.append(mongo_db["levy_4_KN-%d.jobs"%i])
    jobsKN5_exp.append(mongo_db["levy_5_KN-%d.jobs"%i])
    
    recommKN_exp.append(mongo_db["levy_1_KN-%d.recommendations"%i])
    recommKN2_exp.append(mongo_db["levy_2_KN-%d.recommendations"%i])
    recommKN3_exp.append(mongo_db["levy_3_KN-%d.recommendations"%i])
    #recommKN4_exp.append(mongo_db["levy_4_KN-%d.recommendations"%i])
    recommKN5_exp.append(mongo_db["levy_5_KN-%d.recommendations"%i])
    
jobsKN4_exp.append(mongo_db["levy_4_KN.jobs"])
recommKN4_exp.append(mongo_db["levy_4_KN.recommendations"])

# %%
jobsCE_exp = []
jobsCE_exp_1 = []
jobsCE_exp_2_one = []
jobsCE_deter_exp = []
jobs9_exp_one = []

recommCE_exp = []
recommCE_exp_1 = []
recommCE_exp_2_one = []
recommCE_deter_exp = []
recomm9_exp_one = []

#jobsCE_exp.append(mongo_db["levy_CE.jobs"])
#recommCE_exp.append(mongo_db["levy_CE.recommendations"])

jobs9_exp_one.append(mongo_db["levy_9-5.jobs"])
recomm9_exp_one.append(mongo_db["levy_9-5.recommendations"])

jobsCE_exp_2_one.append(mongo_db["levy_CE_2.jobs"])
recommCE_exp_2_one.append(mongo_db["levy_CE_2.recommendations"])

for i in range(25):
    jobsCE_exp.append(mongo_db["levy_CE-%d.jobs"%i])
    jobsCE_exp_1.append(mongo_db["levy_CE_1-%d.jobs"%i])
    jobsCE_deter_exp.append(mongo_db["levy_CE_deter-%d.jobs"%i])
    
    recommCE_exp.append(mongo_db["levy_CE-%d.recommendations"%i])
    recommCE_exp_1.append(mongo_db["levy_CE_1-%d.recommendations"%i])
    recommCE_deter_exp.append(mongo_db["levy_CE_deter-%d.recommendations"%i])

# %%
### get_recomm returns the argmin mu(X)

locs1_exp = functions.get_recomm(recomm1_exp)
locs2_exp = functions.get_recomm(recomm2_exp)
#locs3_exp = functions.get_recomm(recomm3_exp)
locs4_exp = functions.get_recomm(recomm4_exp)
locs5_exp = functions.get_recomm(recomm5_exp)
locs6_exp = functions.get_recomm(recomm6_exp)
locs7_exp = functions.get_recomm(recomm7_exp)
locs8_exp = functions.get_recomm(recomm8_exp)
locs9_exp = functions.get_recomm(recomm9_exp)
locs10_exp = functions.get_recomm(recomm10_exp)
#locs11_exp = functions.get_recomm(recomm11_exp)
locs12_exp = functions.get_recomm(recomm12_exp)
locs_no_initial_exp = functions.get_recomm(recomm_no_initial_exp)
locs_no_initial_exp_2 = functions.get_recomm(recomm_no_initial_exp_2)
locs_no_acq_opt_exp = functions.get_recomm(recomm_no_acq_opt_exp)
locs_no_acq_opt_2_exp = functions.get_recomm(recomm_no_acq_opt_2_exp)

locsKN_exp = functions.get_recomm(recommKN_exp)
locsKN2_exp = functions.get_recomm(recommKN2_exp)
locsKN3_exp = functions.get_recomm(recommKN3_exp)
locsKN4_exp = functions.get_recomm(recommKN4_exp)
locsKN5_exp = functions.get_recomm(recommKN5_exp)

locsCE_exp = functions.get_recomm(recommCE_exp)
locsCE_exp_1 = functions.get_recomm(recommCE_exp_1)
locsCE_deter_exp = functions.get_recomm(recommCE_deter_exp)

locs9_exp_one = functions.get_recomm(recomm9_exp_one)
locsCE_exp_2_one = functions.get_recomm(recommCE_exp_2_one)

locs2_exp_25 = functions.get_recomm(recomm2_exp_25)

# %% [markdown]
# ### Getting immediate Regret IR measure

# %%
def levy_4d(x1,x2,x3,x4):
	w1 = 1 + (x1-1)/4
	w2 = 1 + (x2-1)/4
	w3 = 1 + (x3-1)/4
	w4 = 1 + (x4-1)/4

	a = np.sin(np.pi * w1)**2
	b = ((w1-1)**2)*(1+10*(np.sin(np.pi*w1+1)**2)) + ((w2-1)**2)*(1+10*(np.sin(np.pi*w2+1)**2)) + ((w3-1)**2)*(1+10*(np.sin(np.pi*w3+1)**2)) 
	c = ((w4-1)**2) * (1 + (np.sin(2*np.pi*w4)**2))

	result = a + b + c

	return result

# %%
def get_sugg_obj_exp(locs_exp):
    obj_exp = []
    for exp_num in range(len(locs_exp)):
        objs_iter = []
        locs_cur_exp = locs_exp[exp_num]
        
        for idx in range(len(locs_exp[0])):
            objs_iter.append(levy_4d(*locs_cur_exp[idx]))
            
        obj_exp.append(objs_iter)
        
    return obj_exp

# %%
def log_ir(input_list):
    return np.log10(np.abs(opt_val - levy_4d(*input_list)))

# %%
def get_irs_whole_exp(locs_exp):
    irs_exp = []
    for exp_num in range(len(locs_exp)):
        irs_iter = []
        locs_cur_exp = locs_exp[exp_num]
        
        for idx in range(len(locs_exp[0])):
            
            irs_iter.append(log_ir(locs_cur_exp[idx]))
            
        irs_exp.append(irs_iter)
        
    return irs_exp

# %%
def get_avg_irs(irs_exp):
    avg_irs = []
    for iter_num in range(len(irs_exp[0])):
        cur_iter_irs = []
        for exp_num in range(len(irs_exp)):
            cur_iter_irs.append(irs_exp[exp_num][iter_num])
            
        avg_irs.append(np.average(cur_iter_irs))
        
    return avg_irs

# %%
def get_avg_irs2(irs_exp):
    avg_irs = []
    for iter_num in range(50):
        cur_iter_irs = []
        for exp_num in range(len(irs_exp)):
            cur_iter_irs.append(irs_exp[exp_num][iter_num])
            
        avg_irs.append(np.average(cur_iter_irs))
        
    return avg_irs

# %%
def get_median_irs(irs_exp):
    median_irs = []
    for iter_num in range(len(irs_exp[0])):
        cur_iter_irs = []
        for exp_num in range(len(irs_exp)):
            cur_iter_irs.append(irs_exp[exp_num][iter_num])
        
        median_irs.append(np.median(cur_iter_irs))
        
    return median_irs

# %%
def get_median_irs2(irs_exp):
    median_irs = []
    for iter_num in range(50):
        cur_iter_irs = []
        for exp_num in range(len(irs_exp)):
            cur_iter_irs.append(irs_exp[exp_num][iter_num])
        
        median_irs.append(np.median(cur_iter_irs))
        
    return median_irs

# %%
### get_sugg_obj_exp returns the real function value in suggested location

sugg_obj1_exp = get_sugg_obj_exp(locs1_exp)
sugg_obj2_exp = get_sugg_obj_exp(locs2_exp)
#sugg_obj3_exp = get_sugg_obj_exp(locs3_exp)
sugg_obj4_exp = get_sugg_obj_exp(locs4_exp)
sugg_obj5_exp = get_sugg_obj_exp(locs5_exp)
sugg_obj6_exp = get_sugg_obj_exp(locs6_exp)
sugg_obj7_exp = get_sugg_obj_exp(locs7_exp)
sugg_obj8_exp = get_sugg_obj_exp(locs8_exp)
sugg_obj9_exp = get_sugg_obj_exp(locs9_exp)
sugg_obj10_exp = get_sugg_obj_exp(locs10_exp)
#sugg_obj11_exp = get_sugg_obj_exp(locs11_exp)
sugg_obj12_exp = get_sugg_obj_exp(locs12_exp)

sugg_obj_CE_exp = get_sugg_obj_exp(locsCE_exp)
sugg_obj_CE_exp_1 = get_sugg_obj_exp(locsCE_exp_1)
sugg_obj_CE_deter_exp  = get_sugg_obj_exp(locsCE_deter_exp)

sugg_obj_CE_exp_2_one = get_sugg_obj_exp(locsCE_exp_2_one)

sugg_obj2_exp_25 = get_sugg_obj_exp(locs2_exp_25)

# %%
avg_sugg_obj1_exp = np.average(sugg_obj1_exp, axis=0)
avg_sugg_obj2_exp = np.average(sugg_obj2_exp, axis=0)
#avg_sugg_obj3_exp = np.average(sugg_obj3_exp, axis=0)
avg_sugg_obj4_exp = np.average(sugg_obj4_exp, axis=0)
avg_sugg_obj5_exp = np.average(sugg_obj5_exp, axis=0)
avg_sugg_obj6_exp = np.average(sugg_obj6_exp, axis=0)
avg_sugg_obj7_exp = np.average(sugg_obj7_exp, axis=0)
avg_sugg_obj8_exp = np.average(sugg_obj8_exp, axis=0)
avg_sugg_obj9_exp = np.average(sugg_obj9_exp, axis=0)
avg_sugg_obj10_exp = np.average(sugg_obj10_exp, axis=0)
#avg_sugg_obj11_exp = np.average(sugg_obj11_exp, axis=0)
avg_sugg_obj12_exp = np.average(sugg_obj12_exp, axis=0)

avg_sugg_CE_exp = np.average(sugg_obj_CE_exp, axis=0)
avg_sugg_CE_exp_1 = np.average(sugg_obj_CE_exp_1, axis=0)
avg_sugg_CE_deter_exp = np.average(sugg_obj_CE_deter_exp, axis=0)

avg_sugg_CE_exp_2_one = np.average(sugg_obj_CE_exp_2_one, axis=0)

avg_sugg_obj2_exp_25 = np.average(sugg_obj2_exp_25, axis=0)

# %%
irs1_exp = get_irs_whole_exp(locs1_exp)
irs2_exp = get_irs_whole_exp(locs2_exp)
#irs3_exp = get_irs_whole_exp(locs3_exp)
irs4_exp = get_irs_whole_exp(locs4_exp)
irs5_exp = get_irs_whole_exp(locs5_exp)
irs6_exp = get_irs_whole_exp(locs6_exp)
irs7_exp = get_irs_whole_exp(locs7_exp)
irs8_exp = get_irs_whole_exp(locs8_exp)
irs9_exp = get_irs_whole_exp(locs9_exp)
irs10_exp = get_irs_whole_exp(locs10_exp)
irs12_exp = get_irs_whole_exp(locs12_exp)

irsCE_exp = get_irs_whole_exp(locsCE_exp)
irsCE_exp_1 = get_irs_whole_exp(locsCE_exp_1)
irsCE_deter_exp = get_irs_whole_exp(locsCE_deter_exp)

irsCE_exp_2_one = get_irs_whole_exp(locsCE_exp_2_one)

irs2_exp_25 = get_irs_whole_exp(locs2_exp_25)

# %%
# functions observed_obj returns the real observed min function value in that iteration

obs_obj1_exp = functions.observed_obj(recomm1_exp)
obs_obj2_exp = functions.observed_obj(recomm2_exp)
#obs_obj3_exp = functions.observed_obj(recomm3_exp)
obs_obj4_exp = functions.observed_obj(recomm4_exp)
obs_obj5_exp = functions.observed_obj(recomm5_exp)
obs_obj6_exp = functions.observed_obj(recomm6_exp)
obs_obj7_exp = functions.observed_obj(recomm7_exp)
obs_obj8_exp = functions.observed_obj(recomm8_exp)
obs_obj9_exp = functions.observed_obj(recomm9_exp)
obs_obj10_exp = functions.observed_obj(recomm10_exp)
#obs_obj11_exp = functions.observed_obj(recomm11_exp)
obs_obj12_exp = functions.observed_obj(recomm12_exp)

obs_objCE_exp = functions.observed_obj(recommCE_exp)
obs_objCE_exp_1 = functions.observed_obj(recommCE_exp)
obs_objCE_deter_exp = functions.observed_obj(recommCE_deter_exp)

obs_objCE_exp_2_one = functions.observed_obj(recommCE_exp_2_one)

obs_obj2_exp_25 = functions.observed_obj(recomm2_exp_25)

# %%
avg_obs_obj1_exp = np.average(obs_obj1_exp, axis=0)
avg_obs_obj2_exp = np.average(obs_obj2_exp, axis=0)
#avg_obs_obj3_exp = np.average(obs_obj3_exp, axis=0)
avg_obs_obj4_exp = np.average(obs_obj4_exp, axis=0)
avg_obs_obj5_exp = np.average(obs_obj5_exp, axis=0)
avg_obs_obj6_exp = np.average(obs_obj6_exp, axis=0)
avg_obs_obj7_exp = np.average(obs_obj7_exp, axis=0)
avg_obs_obj8_exp = np.average(obs_obj8_exp, axis=0)
avg_obs_obj9_exp = np.average(obs_obj9_exp, axis=0)
avg_obs_obj10_exp = np.average(obs_obj10_exp, axis=0)
#avg_obs_obj11_exp = np.average(obs_obj11_exp, axis=0)
avg_obs_obj12_exp = np.average(obs_obj12_exp, axis=0)

avg_obs_objCE_exp = np.average(obs_objCE_exp, axis=0)
avg_obs_objCE_exp_1 = np.average(obs_objCE_exp_1, axis=0)
avg_obs_objCE_deter_exp = np.average(obs_objCE_deter_exp, axis=0)

avg_obs_objCE_exp_2_one = np.average(obs_objCE_exp_2_one, axis=0)

avg_obs_obj2_exp_25 = np.average(obs_obj2_exp_25, axis=0)

# %%
plt.figure(figsize=(10,7))
plt.plot(avg_sugg_obj1_exp[:-2], label = 'Mk=10, Mj=1')
plt.plot(avg_sugg_obj2_exp[:-2], label = 'Mk=5, Mj=5')
plt.plot(avg_sugg_obj4_exp[:-2], label = 'Mk=1, Mj=10')
plt.legend()

# %%
plt.figure(figsize=(10,7))
plt.plot(avg_obs_obj1_exp[:-2], label = 'Mk=10, Mj=1')
plt.plot(avg_obs_obj2_exp[:-2], label = 'Mk=5, Mj=5')
plt.plot(avg_obs_obj4_exp[:-2], label = 'Mk=1, Mj=10')
plt.legend()

# %%
plt.figure(figsize=(10,7))
#plt.plot(avg_sugg_obj1_exp[:-2], label = 'Mk=10, Mj=1')
plt.plot(avg_sugg_obj2_exp[:-2], label = 'Mk=5, Mj=5')
plt.plot(avg_sugg_obj4_exp[:-2], label = 'Mk=1, Mj=10')
plt.plot(avg_sugg_obj10_exp[:-2], label = 'Mk=50, Mj=5')
plt.plot(avg_sugg_obj12_exp[:-2], label = 'Mk=200, Mj=1')

plt.legend()

# %%
plt.figure(figsize=(10,7))
#plt.plot(avg_sugg_obj1_exp[:-2], label = 'Mk=10, Mj=1')
#plt.plot(avg_obs_obj2_exp[:-2], label = 'Mk=5, Mj=5')
#plt.plot(avg_obs_obj4_exp[:-2], label = 'Mk=1, Mj=10')
plt.plot(avg_obs_obj10_exp[:-2], label = 'Mk=50, Mj=5')
#plt.plot(avg_obs_obj12_exp[:-2], label = 'Mk=200, Mj=1')
plt.plot(obs_obj12_exp[8][:-2], label='Mk=200, Mj=1 one path')
plt.plot(avg_obs_objCE_exp_2_one[:-2], label='CE, updated ver2')
plt.legend()

# %%
plt.figure(figsize=(10,7))
plt.plot(avg_obs_objCE_exp_2_one[:-2], label='CE, updated observed best ')
plt.plot(avg_sugg_CE_exp_2_one[:-2],label='CE, updated recommended as best')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,7))
#plt.plot(avg_sugg_obj1_exp[:-2], label = 'Mk=10, Mj=1')
#plt.plot(avg_sugg_obj2_exp[:-2], label = 'Mk=5, Mj=5')
#plt.plot(avg_sugg_obj4_exp[:-2], label = 'Mk=1, Mj=10')
#plt.plot(avg_sugg_obj10_exp[:-2], label = 'Mk=50, Mj=5')
plt.plot(avg_sugg_obj12_exp[:-2], label = 'Mk=200, Mj=1')
plt.plot(sugg_obj12_exp[69][:-2],label='Mk=200, Mj=1, one path')
plt.plot(obs_obj12_exp[69][:-2], label='Mk=200, Mj=1, one path observed')

#plt.plot(avg_sugg_CE_exp[:-2], label = 'CE')
#plt.plot(avg_sugg_CE_exp_1[:-2], label = 'CE, increased Simulation Budget')
plt.plot(avg_sugg_CE_exp_2_one[:-2], label = 'CE, updated')

plt.legend()

# %% [markdown]
# ### Mk=5, Mj=5 performance comparison

# %% [markdown]
# #### function value at suggested location

# %%
plt.figure(figsize=(10,7))

plt.plot(avg_sugg_obj2_exp[:-2], label = 'Mk=5, Mj=5')
plt.plot(avg_sugg_obj2_exp_25[:-2], label = 'Mk=5, Mj=5, 25 path')
#plt.plot(sugg_obj2_exp[69][:-2], label = 'Mk=5, Mj=5, one path suggested')
#plt.plot(obs_obj2_exp[69][:-2], label= 'Mk=5, Mj=5, one path observed')

plt.plot(avg_sugg_CE_deter_exp[:-2], label = 'CE deterministic version')
plt.legend()

# %%
levy1_objs = functions.get_objective(recomm1_exp)
levy2_objs = functions.get_objective(recomm2_exp)
#levy3_objs = functions.get_objective(recomm3_exp)
levy4_objs = functions.get_objective(recomm4_exp)
levy5_objs = functions.get_objective(recomm5_exp)
levy6_objs = functions.get_objective(recomm6_exp)
levy7_objs = functions.get_objective(recomm7_exp)
levy8_objs = functions.get_objective(recomm8_exp)
levy9_objs = functions.get_objective(recomm9_exp)
levy10_objs = functions.get_objective(recomm10_exp)
#levy11_objs = functions.get_objective(recomm11_exp)
levy12_objs = functions.get_objective(recomm12_exp)
levy_no_acq_opt_objs = functions.get_objective(recomm_no_acq_opt_exp)
levy_no_acq_opt_2_objs = functions.get_objective(recomm_no_acq_opt_2_exp)
levy_no_initial_objs = functions.get_objective(recomm_no_initial_exp)
levy_no_initial_objs_2 = functions.get_objective(recomm_no_initial_exp_2)

levyKN_objs = functions.get_objective(recommKN_exp)
levyKN2_objs = functions.get_objective(recommKN2_exp)
levyKN3_objs = functions.get_objective(recommKN3_exp)
levyKN4_objs = functions.get_objective(recommKN4_exp)
levyKN5_objs = functions.get_objective(recommKN5_exp)

levyCE_objs = functions.get_objective(recommCE_exp)
levyCE_objs_1 = functions.get_objective(recommCE_exp_1)
levyCE_deter_objs = functions.get_objective(recommCE_deter_exp)
levyCE_objs_2_one = functions.get_objective(recommCE_exp_2_one)
levy9_objs_one = functions.get_objective(recomm9_exp_one)

# %%
levy1_objs = np.average(levy1_objs, axis = 0)
levy2_objs = np.average(levy2_objs, axis = 0)
levy4_objs = np.average(levy4_objs, axis = 0)
#levy3_objs = np.average(levy3_objs, axis = 0)
levy5_objs = np.average(levy5_objs, axis = 0)
levy6_objs = np.average(levy6_objs, axis = 0)
levy7_objs = np.average(levy7_objs, axis = 0)
levy8_objs = np.average(levy8_objs, axis = 0)
levy9_objs = np.average(levy9_objs, axis = 0)
levy10_objs = np.average(levy10_objs, axis = 0)
#levy11_objs = np.average(levy11_objs, axis = 0)
levy12_objs = np.average(levy12_objs, axis = 0)
levy_no_acq_opt_objs = np.average(levy_no_acq_opt_objs, axis = 0)
levy_no_acq_opt_2_objs = np.average(levy_no_acq_opt_2_objs, axis = 0)
levy_no_initial_objs = np.average(levy_no_initial_objs, axis = 0)
levy_no_initial_objs_2 = np.average(levy_no_initial_objs_2, axis = 0)

levyKN_objs = np.average(levyKN_objs, axis = 0)
levyKN2_objs = np.average(levyKN2_objs, axis = 0)
levyKN3_objs = np.average(levyKN3_objs, axis = 0)
levyKN4_objs = np.average(levyKN4_objs, axis = 0)
levyKN5_objs = np.average(levyKN5_objs, axis = 0)

levyCE_objs = np.average(levyCE_objs, axis = 0)
levyCE_objs_1 = np.average(levyCE_objs_1, axis = 0)
levyCE_deter = np.average(levyCE_deter_objs, axis=0)

levyCE_objs_2_one = np.average(levyCE_objs_2_one, axis = 0)

levy9_objs_one = np.average(levy9_objs_one, axis = 0)

# %%
plt.figure(figsize=(10,7))

plt.plot(levyCE_objs[:-2], label = 'CE')
#plt.plot(levyCE_objs_1[:-2], label = 'CE, increased Simulation Budget')

plt.plot(levyCE_objs_2_one[:-2], label = 'CE updated')
#plt.plot(levy9_objs_one[:-2], label = 'Mk20 Mj5 one path')
#plt.plot(levy_no_acq_opt_objs[:-2], label = 'No acq opt')
#plt.plot(levy_no_acq_opt_2_objs[:-2], label = 'No acq opt, Mk=20')
#plt.plot(levy_no_initial_objs[:-2], label = 'No initial')
plt.plot(levy12_objs[:-2], label = 'Mk=200, Mj=1')
#plt.plot(levy10_objs[:-2], label = 'Mk=50, Mj=5')
#plt.plot(levy9_objs[:-2], label = 'Mk=20, Mj=5')
#plt.plot(levy8_objs[:-2], label = 'Mk=10, Mj=5')
#plt.plot(levy2_objs[:-2], label = 'Mk=5, Mj=5')
#plt.plot(levy6_objs[:-2], label = 'Mk=3, Mj=5')
#plt.plot(levy7_objs[:-2], label = 'Mk=1, Mj=5')
#plt.plot(levy11_objs[:-2], label = 'using KN')
plt.ylim(-2,10)
plt.legend()

# %%
locs1_exp[0][1]
# Out:
# [3.6070670399315983,
#  2.448663848301191,
#  -1.0238771749382476,
#  -1.8477078993619855]

# %%
locsCE_exp[0][1]
# Out:
# [1.3059743666088561, 1.193699488730637, 0.5684886984501247, -1.459066030557476]

# %%
irs1_median = get_median_irs(irs1_exp)
irs2_median = get_median_irs(irs2_exp)
#irs3_median = get_median_irs(irs3_exp)
irs4_median = get_median_irs(irs4_exp)
irs5_median = get_median_irs(irs5_exp)
irs6_median = get_median_irs(irs6_exp)
irs7_median = get_median_irs(irs7_exp)
irs8_median = get_median_irs(irs8_exp)
irs9_median = get_median_irs(irs9_exp)
irs10_median = get_median_irs(irs10_exp)
irs12_median = get_median_irs(irs12_exp)


irsCE_median = get_median_irs(irsCE_exp)
irsCE_median_1 = get_median_irs(irsCE_exp_1)
irsCE_deter_median = get_median_irs(irsCE_deter_exp)

irsCE_median_2_one = get_median_irs(irsCE_exp_2_one)

# %%
irs1_avg = get_avg_irs(irs1_exp)
irs2_avg = get_avg_irs(irs2_exp)
#irs3_avg = get_avg_irs(irs3_exp)
irs4_avg = get_avg_irs(irs4_exp)
irs5_avg = get_avg_irs(irs5_exp)
irs6_avg = get_avg_irs(irs6_exp)
irs7_avg = get_avg_irs(irs7_exp)
irs8_avg = get_avg_irs(irs8_exp)
irs9_avg = get_avg_irs(irs9_exp)
irs10_avg = get_avg_irs(irs10_exp)
irs12_avg = get_avg_irs(irs12_exp)


irsCE_avg = get_avg_irs(irsCE_exp)
irsCE_avg_1 = get_avg_irs(irsCE_exp_1)
irsCE_deter_avg = get_avg_irs(irsCE_deter_exp)

irsCE_avg_2_one = get_avg_irs(irsCE_exp_2_one)

# %%
plt.figure(figsize=(10,7))
plt.plot(irs2_median,label='Mk=5, Mj=5')
#plt.plot(irs4_median,label='Mk=1, Mj=10')
plt.plot(irs10_median,label='Mk=1, Mj=1')
plt.plot(irs12_median,label='Mk=1, Mj=10')

#plt.plot(irsCE_median, label='CE')
#plt.plot(irsCE_median_1, label='CE, increased Simulation Budget')
#plt.plot(irsCE_deter_median, label='CE deterministic version')
plt.legend()

# %%
plt.figure(figsize=(10,7))

#plt.plot(irs9_median_one,label='M20 one path')
#plt.plot(irsCE_median,label='CE')
#plt.plot(irsCE_median_1,label='CE, increased Simulation Budget')
#plt.plot(irsCE_median_2_one,label='CE, updated')
plt.plot(irs12_median,label='Mk=200, Mj=1')
#plt.plot(irs_no_initial_median,label='no initial')
#plt.plot(irs_no_acq_opt_median,label='no acq opt')
#plt.plot(irs_no_acq_opt_2_median,label='no acq opt_2, Mk=20')
#plt.plot(irs10_median,label='Mk=50, Mj=5')
plt.plot(irs9_median,label='Mk=20, Mj=5')
#plt.plot(irs8_median,label='Mk=10, Mj=5')
#plt.plot(irs2_median,label='Mk=5, Mj=5')
#plt.plot(irs6_median,label='Mk=3, Mj=5')

#plt.plot(irs7_median,label='Mk=1, Mj=5')
#plt.plot(irs11_median,label='using KN')
plt.legend()

# %%
plt.figure(figsize=(10,7))
#plt.plot(irsKN5_avg,label='KN5')
#plt.plot(irsKN4_avg,label='KN4')
#plt.plot(irsKN3_avg,label='KN3')
#plt.plot(irsKN2_avg,label='KN2')
plt.plot(irsCE_avg,label='CE')
plt.plot(irsCE_avg_1,label='CE, increased Simulation Budget')

#plt.plot(irs_no_initial_avg,label='no initial')
#plt.plot(irs_no_acq_opt_avg,label='no acq opt')
#plt.plot(irs_no_acq_opt_2_avg,label='no acq opt, Mk=20')
plt.plot(irs12_avg,label='Mk=200, Mj=1')
#plt.plot(irs10_avg,label='Mk=50, Mj=5')
#plt.plot(irs9_avg,label='Mk=20, Mj=5')
#plt.plot(irs8_avg,label='Mk=10, Mj=5')
#plt.plot(irs2_avg,label='Mk=5, Mj=5')
#plt.plot(irs6_avg,label='Mk=3, Mj=5')

#plt.plot(irs7_avg,label='Mk=1, Mj=5')
#plt.plot(irs11_avg,label='using KN')
plt.legend()

# %%
plt.figure(figsize=(10,7))
#plt.plot(irsKN5_avg,label='KN5')
#plt.plot(irsKN4_avg,label='KN4')
#plt.plot(irsKN3_avg,label='KN3')
#plt.plot(irsKN2_avg,label='KN2')
plt.plot(irsCE_avg,label='CE')
plt.plot(irsCE_avg_1,label='CE, increased Simulation Budget')

#plt.plot(irs_no_initial_avg,label='no initial')
#plt.plot(irs_no_acq_opt_avg,label='no acq opt')
#plt.plot(irs_no_acq_opt_2_avg,label='no acq opt, Mk=20')
plt.plot(irs12_avg,label='Mk=200, Mj=1')
#plt.plot(irs10_avg,label='Mk=50, Mj=5')
#plt.plot(irs9_avg,label='Mk=20, Mj=5')
#plt.plot(irs8_avg,label='Mk=10, Mj=5')
plt.plot(irs2_avg,label='Mk=5, Mj=5')
#plt.plot(irs6_avg,label='Mk=3, Mj=5')

#plt.plot(irs7_avg,label='Mk=1, Mj=5')
#plt.plot(irs11_avg,label='using KN')
plt.legend()

# %%
plt.figure(figsize=(10,7))

#plt.plot(irsCE_avg,label='CE')
#plt.plot(irsCE_avg_1,label='CE, increased Simulation Budget')
plt.plot(irsCE_deter_avg, label='CE deterministic version')

#plt.plot(irs_no_initial_avg,label='no initial')
#plt.plot(irs_no_acq_opt_avg,label='no acq opt')
#plt.plot(irs_no_acq_opt_2_avg,label='no acq opt, Mk=20')
#plt.plot(irs12_avg,label='Mk=200, Mj=1')
#plt.plot(irs10_avg,label='Mk=50, Mj=5')
#plt.plot(irs9_avg,label='Mk=20, Mj=5')
#plt.plot(irs8_avg,label='Mk=10, Mj=5')
plt.plot(irs2_avg,label='Mk=5, Mj=5')
#plt.plot(irs6_avg,label='Mk=3, Mj=5')

#plt.plot(irs7_avg,label='Mk=1, Mj=5')
#plt.plot(irs11_avg,label='using KN')
plt.legend()

# %%
recomm1_exp[0]

# %%
recomm1_exp[0].find()

# %%
documents = recomm1_exp[0].find()

# %%
for doc in documents:
    print(compression.decompress_nested_container(doc))
    print()
