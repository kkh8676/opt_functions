# %%
import pymongo
from spearmint.utils import compression
from spearmint.utils import functions
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from spearmint.tasks import input_space
sns.set()

# %%
mongo_conn = pymongo.MongoClient('127.0.0.1',27017)
mongo_conn.list_database_names()

mongo_db = mongo_conn['spearmint']

# %%
collection_list = mongo_db.list_collection_names()

# %%
exp_name = 'sep_drop_wave'

# %% [markdown]
# ### EI 0.1 version

# %%
jobs_initial0_Mk0_ls01_amp1_EI_01_exp = []
jobs_initial0_Mk0_ls01_amp10_EI_01_exp = []
jobs_initial0_Mk0_ls05_amp1_EI_01_exp = []
jobs_initial0_Mk0_ls05_amp10_EI_01_exp = []
jobs_initial0_Mk0_ls10_amp1_EI_01_exp = []
jobs_initial0_Mk0_1s10_amp10_EI_01_exp = []

jobs_initial0_Mk0_ls005_amp1_EI_01_exp = []
jobs_initial0_Mk0_ls005_amp10_EI_01_exp = []


recomm_initial0_Mk0_ls01_amp1_EI_01_exp = []
recomm_initial0_Mk0_ls01_amp10_EI_01_exp = []
recomm_initial0_Mk0_ls05_amp1_EI_01_exp = []
recomm_initial0_Mk0_ls05_amp10_EI_01_exp = []
recomm_initial0_Mk0_ls10_amp1_EI_01_exp = []
recomm_initial0_Mk0_1s10_amp10_EI_01_exp = []

recomm_initial0_Mk0_ls005_amp1_EI_01_exp = []
recomm_initial0_Mk0_ls005_amp10_EI_01_exp = []

for i in range(25):
    if "%s_initial0_Mk0_ls01_amp1_EI_0.1-%d.recommendations"%(exp_name,i) in collection_list: jobs_initial0_Mk0_ls01_amp1_EI_01_exp.append(mongo_db["%s_initial0_Mk0_ls01_amp1_EI_0.1-%d.jobs"%(exp_name,i)])
    if "%s_initial0_Mk0_ls01_amp10_EI-%d.recommendations"%(exp_name,i) in collection_list: jobs_initial0_Mk0_ls01_amp10_EI_01_exp.append(mongo_db["%s_initial0_Mk0_ls01_amp10_EI-%d.jobs"%(exp_name,i)])
    if "%s_initial0_Mk0_ls05_amp1_EI_0.1-%d.recommendations"%(exp_name,i) in collection_list: jobs_initial0_Mk0_ls05_amp1_EI_01_exp.append(mongo_db["%s_initial0_Mk0_ls05_amp1_EI_0.1-%d.jobs"%(exp_name,i)])
    if "%s_initial0_Mk0_ls05_amp10_EI_0.1-%d.recommendations"%(exp_name,i) in collection_list: jobs_initial0_Mk0_ls05_amp10_EI_01_exp.append(mongo_db["%s_initial0_Mk0_ls05_amp10_EI_0.1-%d.jobs"%(exp_name,i)])
    if "%s_initial0_Mk0_ls10_amp1_EI_0.1-%d.recommendations"%(exp_name,i) in collection_list: jobs_initial0_Mk0_ls10_amp1_EI_01_exp.append(mongo_db["%s_initial0_Mk0_ls10_amp1_EI_0.1-%d.jobs"%(exp_name,i)])
    if "%s_initial0_Mk0_ls10_amp10_EI_0.1-%d.recommendations"%(exp_name,i) in collection_list: jobs_initial0_Mk0_1s10_amp10_EI_01_exp.append(mongo_db["%s_initial0_Mk0_ls10_amp10_EI_0.1-%d.jobs"%(exp_name,i)])
        
    if "%s_initial0_Mk0_ls005_amp1_EI_0.1-%d.recommendations"%(exp_name,i) in collection_list: jobs_initial0_Mk0_ls005_amp1_EI_01_exp.append(mongo_db["%s_initial0_Mk0_ls005_amp1_EI_0.1-%d.jobs"%(exp_name,i)])
    if "%s_initial0_Mk0_ls005_amp10_EI_0.1-%d.recommendations"%(exp_name,i) in collection_list: jobs_initial0_Mk0_ls005_amp10_EI_01_exp.append(mongo_db["%s_initial0_Mk0_ls005_amp10_EI_0.1-%d.jobs"%(exp_name,i)])
        
    if "%s_initial0_Mk0_ls01_amp1_EI_0.1-%d.recommendations"%(exp_name,i) in collection_list: recomm_initial0_Mk0_ls01_amp1_EI_01_exp.append(mongo_db["%s_initial0_Mk0_ls01_amp1_EI_0.1-%d.recommendations"%(exp_name,i)])
    if "%s_initial0_Mk0_ls01_amp10_EI-%d.recommendations"%(exp_name,i) in collection_list: recomm_initial0_Mk0_ls01_amp10_EI_01_exp.append(mongo_db["%s_initial0_Mk0_ls01_amp10_EI-%d.recommendations"%(exp_name,i)])
    if "%s_initial0_Mk0_ls05_amp1_EI_0.1-%d.recommendations"%(exp_name,i) in collection_list: recomm_initial0_Mk0_ls05_amp1_EI_01_exp.append(mongo_db["%s_initial0_Mk0_ls05_amp1_EI_0.1-%d.recommendations"%(exp_name,i)])
    if "%s_initial0_Mk0_ls05_amp10_EI_0.1-%d.recommendations"%(exp_name,i) in collection_list: recomm_initial0_Mk0_ls05_amp10_EI_01_exp.append(mongo_db["%s_initial0_Mk0_ls05_amp10_EI_0.1-%d.recommendations"%(exp_name,i)])
    if "%s_initial0_Mk0_ls10_amp1_EI_0.1-%d.recommendations"%(exp_name,i) in collection_list: recomm_initial0_Mk0_ls10_amp1_EI_01_exp.append(mongo_db["%s_initial0_Mk0_ls10_amp1_EI_0.1-%d.recommendations"%(exp_name,i)])
    if "%s_initial0_Mk0_ls10_amp10_EI_0.1-%d.recommendations"%(exp_name,i) in collection_list: recomm_initial0_Mk0_1s10_amp10_EI_01_exp.append(mongo_db["%s_initial0_Mk0_ls10_amp10_EI_0.1-%d.recommendations"%(exp_name,i)])
        
    if "%s_initial0_Mk0_ls005_amp1_EI_0.1-%d.recommendations"%(exp_name,i) in collection_list: recomm_initial0_Mk0_ls005_amp1_EI_01_exp.append(mongo_db["%s_initial0_Mk0_ls005_amp1_EI_0.1-%d.recommendations"%(exp_name,i)])
    if "%s_initial0_Mk0_ls005_amp10_EI_0.1-%d.recommendations"%(exp_name,i) in collection_list: recomm_initial0_Mk0_ls005_amp10_EI_01_exp.append(mongo_db["%s_initial0_Mk0_ls005_amp10_EI_0.1-%d.recommendations"%(exp_name,i)])

# %% [markdown]
# ### EI 0.5 version

# %%
jobs_initial0_Mk0_ls01_amp1_EI_05_exp = []
jobs_initial0_Mk0_ls01_amp10_EI_05_exp = []
jobs_initial0_Mk0_ls05_amp1_EI_05_exp = []
jobs_initial0_Mk0_ls05_amp10_EI_05_exp = []
jobs_initial0_Mk0_ls10_amp1_EI_05_exp = []
jobs_initial0_Mk0_1s10_amp10_EI_05_exp = []

recomm_initial0_Mk0_ls01_amp1_EI_05_exp = []
recomm_initial0_Mk0_ls01_amp10_EI_05_exp = []
recomm_initial0_Mk0_ls05_amp1_EI_05_exp = []
recomm_initial0_Mk0_ls05_amp10_EI_05_exp = []
recomm_initial0_Mk0_ls10_amp1_EI_05_exp = []
recomm_initial0_Mk0_1s10_amp10_EI_05_exp = []

for i in range(25):
    if "%s_initial0_Mk0_ls01_amp1_EI_0.5-%d.recommendations"%(exp_name,i) in collection_list: jobs_initial0_Mk0_ls01_amp1_EI_05_exp.append(mongo_db["%s_initial0_Mk0_ls01_amp1_EI_0.5-%d.jobs"%(exp_name,i)])
    if "%s_initial0_Mk0_ls01_amp10_EI_0.5-%d.recommendations"%(exp_name,i) in collection_list: jobs_initial0_Mk0_ls01_amp10_EI_05_exp.append(mongo_db["%s_initial0_Mk0_ls01_amp10_EI_0.5-%d.jobs"%(exp_name,i)])
    if "%s_initial0_Mk0_ls05_amp1_EI_0.5-%d.recommendations"%(exp_name,i) in collection_list: jobs_initial0_Mk0_ls05_amp1_EI_05_exp.append(mongo_db["%s_initial0_Mk0_ls05_amp1_EI_0.5-%d.jobs"%(exp_name,i)])
    if "%s_initial0_Mk0_ls05_amp10_EI_0.5-%d.recommendations"%(exp_name,i) in collection_list: jobs_initial0_Mk0_ls05_amp10_EI_05_exp.append(mongo_db["%s_initial0_Mk0_ls05_amp10_EI_0.5-%d.jobs"%(exp_name,i)])
    if "%s_initial0_Mk0_ls10_amp1_EI_0.5-%d.recommendations"%(exp_name,i) in collection_list: jobs_initial0_Mk0_ls10_amp1_EI_05_exp.append(mongo_db["%s_initial0_Mk0_ls10_amp1_EI_0.5-%d.jobs"%(exp_name,i)])
    if "%s_initial0_Mk0_ls10_amp10_EI_0.5-%d.recommendations"%(exp_name,i) in collection_list: jobs_initial0_Mk0_1s10_amp10_EI_05_exp.append(mongo_db["%s_initial0_Mk0_ls10_amp10_EI_0.5-%d.jobs"%(exp_name,i)])
        
    if "%s_initial0_Mk0_ls01_amp1_EI_0.5-%d.recommendations"%(exp_name,i) in collection_list: recomm_initial0_Mk0_ls01_amp1_EI_05_exp.append(mongo_db["%s_initial0_Mk0_ls01_amp1_EI_0.5-%d.recommendations"%(exp_name,i)])
    if "%s_initial0_Mk0_ls01_amp10_EI_0.5-%d.recommendations"%(exp_name,i) in collection_list: recomm_initial0_Mk0_ls01_amp10_EI_05_exp.append(mongo_db["%s_initial0_Mk0_ls01_amp10_EI_0.5-%d.recommendations"%(exp_name,i)])
    if "%s_initial0_Mk0_ls05_amp1_EI_0.5-%d.recommendations"%(exp_name,i) in collection_list: recomm_initial0_Mk0_ls05_amp1_EI_05_exp.append(mongo_db["%s_initial0_Mk0_ls05_amp1_EI_0.5-%d.recommendations"%(exp_name,i)])
    if "%s_initial0_Mk0_ls05_amp10_EI_0.5-%d.recommendations"%(exp_name,i) in collection_list: recomm_initial0_Mk0_ls05_amp10_EI_05_exp.append(mongo_db["%s_initial0_Mk0_ls05_amp10_EI_0.5-%d.recommendations"%(exp_name,i)])
    if "%s_initial0_Mk0_ls10_amp1_EI_0.5-%d.recommendations"%(exp_name,i) in collection_list: recomm_initial0_Mk0_ls10_amp1_EI_05_exp.append(mongo_db["%s_initial0_Mk0_ls10_amp1_EI_0.5-%d.recommendations"%(exp_name,i)])
    if "%s_initial0_Mk0_ls10_amp10_EI_0.5-%d.recommendations"%(exp_name,i) in collection_list: recomm_initial0_Mk0_1s10_amp10_EI_05_exp.append(mongo_db["%s_initial0_Mk0_ls10_amp10_EI_0.5-%d.recommendations"%(exp_name,i)])

# %% [markdown]
# ### EI 1.0 version

# %%
jobs_initial0_Mk0_ls01_amp1_EI_10_exp = []
jobs_initial0_Mk0_ls01_amp10_EI_10_exp = []
jobs_initial0_Mk0_ls05_amp1_EI_10_exp = []
jobs_initial0_Mk0_ls05_amp10_EI_10_exp = []
jobs_initial0_Mk0_ls10_amp1_EI_10_exp = []
jobs_initial0_Mk0_1s10_amp10_EI_10_exp = []

recomm_initial0_Mk0_ls01_amp1_EI_10_exp = []
recomm_initial0_Mk0_ls01_amp10_EI_10_exp = []
recomm_initial0_Mk0_ls05_amp1_EI_10_exp = []
recomm_initial0_Mk0_ls05_amp10_EI_10_exp = []
recomm_initial0_Mk0_ls10_amp1_EI_10_exp = []
recomm_initial0_Mk0_1s10_amp10_EI_10_exp = []

for i in range(25):
    if "%s_initial0_Mk0_ls01_amp1_EI_1.0-%d.recommendations"%(exp_name,i) in collection_list: jobs_initial0_Mk0_ls01_amp1_EI_10_exp.append(mongo_db["%s_initial0_Mk0_ls01_amp1_EI_1.0-%d.jobs"%(exp_name,i)])
    if "%s_initial0_Mk0_ls01_amp10_EI_1.0-%d.recommendations"%(exp_name,i) in collection_list: jobs_initial0_Mk0_ls01_amp10_EI_10_exp.append(mongo_db["%s_initial0_Mk0_ls01_amp10_EI_1.0-%d.jobs"%(exp_name,i)])
    if "%s_initial0_Mk0_ls05_amp1_EI_1.0-%d.recommendations"%(exp_name,i) in collection_list: jobs_initial0_Mk0_ls05_amp1_EI_10_exp.append(mongo_db["%s_initial0_Mk0_ls05_amp1_EI_1.0-%d.jobs"%(exp_name,i)])
    if "%s_initial0_Mk0_ls05_amp10_EI_1.0-%d.recommendations"%(exp_name,i) in collection_list: jobs_initial0_Mk0_ls05_amp10_EI_10_exp.append(mongo_db["%s_initial0_Mk0_ls05_amp10_EI_1.0-%d.jobs"%(exp_name,i)])
    if "%s_initial0_Mk0_ls10_amp1_EI_1.0-%d.recommendations"%(exp_name,i) in collection_list: jobs_initial0_Mk0_ls10_amp1_EI_10_exp.append(mongo_db["%s_initial0_Mk0_ls10_amp1_EI_1.0-%d.jobs"%(exp_name,i)])
    if "%s_initial0_Mk0_ls10_amp10_EI_1.0-%d.recommendations"%(exp_name,i) in collection_list: jobs_initial0_Mk0_1s10_amp10_EI_10_exp.append(mongo_db["%s_initial0_Mk0_ls10_amp10_EI_1.0-%d.jobs"%(exp_name,i)])
        
    if "%s_initial0_Mk0_ls01_amp1_EI_1.0-%d.recommendations"%(exp_name,i) in collection_list: recomm_initial0_Mk0_ls01_amp1_EI_10_exp.append(mongo_db["%s_initial0_Mk0_ls01_amp1_EI_1.0-%d.recommendations"%(exp_name,i)])
    if "%s_initial0_Mk0_ls01_amp10_EI_1.0-%d.recommendations"%(exp_name,i) in collection_list: recomm_initial0_Mk0_ls01_amp10_EI_10_exp.append(mongo_db["%s_initial0_Mk0_ls01_amp10_EI_1.0-%d.recommendations"%(exp_name,i)])
    if "%s_initial0_Mk0_ls05_amp1_EI_1.0-%d.recommendations"%(exp_name,i) in collection_list: recomm_initial0_Mk0_ls05_amp1_EI_10_exp.append(mongo_db["%s_initial0_Mk0_ls05_amp1_EI_1.0-%d.recommendations"%(exp_name,i)])
    if "%s_initial0_Mk0_ls05_amp10_EI_1.0-%d.recommendations"%(exp_name,i) in collection_list: recomm_initial0_Mk0_ls05_amp10_EI_10_exp.append(mongo_db["%s_initial0_Mk0_ls05_amp10_EI_1.0-%d.recommendations"%(exp_name,i)])
    if "%s_initial0_Mk0_ls10_amp1_EI_1.0-%d.recommendations"%(exp_name,i) in collection_list: recomm_initial0_Mk0_ls10_amp1_EI_10_exp.append(mongo_db["%s_initial0_Mk0_ls10_amp1_EI_1.0-%d.recommendations"%(exp_name,i)])
    if "%s_initial0_Mk0_ls10_amp10_EI_1.0-%d.recommendations"%(exp_name,i) in collection_list: recomm_initial0_Mk0_1s10_amp10_EI_10_exp.append(mongo_db["%s_initial0_Mk0_ls10_amp10_EI_1.0-%d.recommendations"%(exp_name,i)])

# %% [markdown]
# ### Get objective method gets the predicted optimal value in GP model

# %%
locs_initial0_Mk0_ls01_amp1_EI_01_exp = functions.get_recomm_loc(recomm_initial0_Mk0_ls01_amp1_EI_01_exp)
locs_initial0_Mk0_ls01_amp10_EI_01_exp = functions.get_recomm_loc(recomm_initial0_Mk0_ls01_amp10_EI_01_exp)
locs_initial0_Mk0_ls05_amp1_EI_01_exp = functions.get_recomm_loc(recomm_initial0_Mk0_ls05_amp1_EI_01_exp)
locs_initial0_Mk0_ls05_amp10_EI_01_exp = functions.get_recomm_loc(recomm_initial0_Mk0_ls05_amp10_EI_01_exp)
locs_initial0_Mk0_ls10_amp1_EI_01_exp = functions.get_recomm_loc(recomm_initial0_Mk0_ls10_amp1_EI_01_exp)
locs_initial0_Mk0_ls10_amp10_EI_01_exp = functions.get_recomm_loc(recomm_initial0_Mk0_1s10_amp10_EI_01_exp)

locs_initial0_Mk0_ls005_amp1_EI_01_exp = functions.get_recomm_loc(recomm_initial0_Mk0_ls005_amp1_EI_01_exp)
locs_initial0_Mk0_ls005_amp10_EI_01_exp = functions.get_recomm_loc(recomm_initial0_Mk0_ls005_amp10_EI_01_exp)

# %%
locs_initial0_Mk0_ls01_amp1_EI_05_exp = functions.get_recomm_loc(recomm_initial0_Mk0_ls01_amp1_EI_05_exp)
locs_initial0_Mk0_ls01_amp10_EI_05_exp = functions.get_recomm_loc(recomm_initial0_Mk0_ls01_amp10_EI_05_exp)
locs_initial0_Mk0_ls05_amp1_EI_05_exp = functions.get_recomm_loc(recomm_initial0_Mk0_ls05_amp1_EI_05_exp)
locs_initial0_Mk0_ls05_amp10_EI_05_exp = functions.get_recomm_loc(recomm_initial0_Mk0_ls05_amp10_EI_05_exp)
locs_initial0_Mk0_ls10_amp1_EI_05_exp = functions.get_recomm_loc(recomm_initial0_Mk0_ls10_amp1_EI_05_exp)
locs_initial0_Mk0_ls10_amp10_EI_05_exp = functions.get_recomm_loc(recomm_initial0_Mk0_1s10_amp10_EI_05_exp)

# %%
locs_initial0_Mk0_ls01_amp1_EI_10_exp = functions.get_recomm_loc(recomm_initial0_Mk0_ls01_amp1_EI_10_exp)
locs_initial0_Mk0_ls01_amp10_EI_10_exp = functions.get_recomm_loc(recomm_initial0_Mk0_ls01_amp10_EI_10_exp)
locs_initial0_Mk0_ls05_amp1_EI_10_exp = functions.get_recomm_loc(recomm_initial0_Mk0_ls05_amp1_EI_10_exp)
locs_initial0_Mk0_ls05_amp10_EI_10_exp = functions.get_recomm_loc(recomm_initial0_Mk0_ls05_amp10_EI_10_exp)
locs_initial0_Mk0_ls10_amp1_EI_10_exp = functions.get_recomm_loc(recomm_initial0_Mk0_ls10_amp1_EI_10_exp)
locs_initial0_Mk0_ls10_amp10_EI_10_exp = functions.get_recomm_loc(recomm_initial0_Mk0_1s10_amp10_EI_10_exp)

# %% [markdown]
# ### Getting immediate Regret IR measure

# %%
def drop_wave(x1,x2):
	numerator = 1 + np.cos(12*((x1**2 + x2**2)**0.5))
	delimiter = 0.5 * (x1**2 + x2**2) + 2

	result = - numerator / delimiter

	return result

# %%
opt_val = -1

# %%
func = drop_wave

# %%
def get_sugg_obj_exp(locs_exp):
    obj_exp = []
    for exp_num in range(len(locs_exp)):
        objs_iter = []
        locs_cur_exp = locs_exp[exp_num]
        
        for idx in range(len(locs_exp[exp_num])):
            objs_iter.append(func(*locs_cur_exp[idx]))
            
        obj_exp.append(objs_iter)
        
    return obj_exp

# %%
def log_ir(input_list):
    return np.log10(np.abs(opt_val - func(*input_list)))

# %%
def get_irs_whole_exp(locs_exp):
    irs_exp = []
    for exp_num in range(len(locs_exp)):
        irs_iter = []
        locs_cur_exp = locs_exp[exp_num]
        
        for idx in range(len(locs_exp[0])):
            
            irs_iter.append(log_ir(locs_cur_exp[idx]))
            
        irs_exp.append(irs_iter)
        
    return irs_exp

# %%
def get_avg_irs(irs_exp):
    avg_irs = []
    for iter_num in range(len(irs_exp[0])):
        cur_iter_irs = []
        for exp_num in range(len(irs_exp)):
            cur_iter_irs.append(irs_exp[exp_num][iter_num])
            
        avg_irs.append(np.average(cur_iter_irs))
        
    return avg_irs

# %%
def get_median_irs(irs_exp):
    median_irs = []
    for iter_num in range(len(irs_exp[0])):
        cur_iter_irs = []
        for exp_num in range(len(irs_exp)):
            cur_iter_irs.append(irs_exp[exp_num][iter_num])
        
        median_irs.append(np.median(cur_iter_irs))
        
    return median_irs

# %%
def get_std_err_irs(irs_exp):
    std_err_irs = []
    for iter_num in range(len(irs_exp[0])):
        cur_iter_irs = []
        for exp_num in range(len(irs_exp)):
            cur_iter_irs.append(irs_exp[exp_num][iter_num])
            
        std_err_irs.append(np.std(cur_iter_irs))
        
    return std_err_irs

# %%
minimum = 80
for exp in locs_initial0_Mk0_ls10_amp10_EI_05_exp:
    minimum = minimum if len(exp) > minimum else len(exp)
    
locs_initial0_Mk0_ls10_amp10_EI_05_exp = [list_[:minimum] for list_ in locs_initial0_Mk0_ls10_amp10_EI_05_exp]
print(minimum)
# Out:
# 80

# %%
minimum = 80
for exp in locs_initial0_Mk0_ls05_amp10_EI_01_exp:
    minimum = minimum if len(exp) > minimum else len(exp)
    
locs_initial0_Mk0_ls05_amp10_EI_01_exp = [list_[:minimum] for list_ in locs_initial0_Mk0_ls05_amp10_EI_01_exp]
print(minimum)
# Out:
# 80

# %% [markdown]
# ### Getting the 'real' value of functions at suggested locations

# %%
sugg_obj_initial0_Mk0_ls01_amp1_EI_01_exp = get_sugg_obj_exp(locs_initial0_Mk0_ls01_amp1_EI_01_exp)
sugg_obj_initial0_Mk0_ls01_amp10_EI_01_exp = get_sugg_obj_exp(locs_initial0_Mk0_ls01_amp10_EI_01_exp)
sugg_obj_initial0_Mk0_ls05_amp1_EI_01_exp = get_sugg_obj_exp(locs_initial0_Mk0_ls05_amp1_EI_01_exp)
sugg_obj_initial0_Mk0_ls05_amp10_EI_01_exp = get_sugg_obj_exp(locs_initial0_Mk0_ls05_amp10_EI_01_exp)
sugg_obj_initial0_Mk0_ls10_amp1_EI_01_exp = get_sugg_obj_exp(locs_initial0_Mk0_ls10_amp1_EI_01_exp)
sugg_obj_initial0_Mk0_ls10_amp10_EI_01_exp = get_sugg_obj_exp(locs_initial0_Mk0_ls10_amp10_EI_01_exp)

sugg_obj_initial0_Mk0_ls005_amp1_EI_01_exp = get_sugg_obj_exp(locs_initial0_Mk0_ls005_amp1_EI_01_exp)
sugg_obj_initial0_Mk0_ls005_amp10_EI_01_exp = get_sugg_obj_exp(locs_initial0_Mk0_ls005_amp10_EI_01_exp)

# %%
locs_initial0_Mk0_ls005_amp10_EI_01_exp
# Out:
# [[[-5.12, -5.12],
#   [2.9498009122540685, -0.9992616324508594],
#   [2.335574073209113, -1.1780602575582875],
#   [2.353708066544759, -1.0609895159331337],
#   [2.4217521131710704, -1.2413795688352458],
#   [2.0997565569342784, -1.2216524367081663],
#   [2.3304540216619873, -1.0977342128336582],
#   [3.141799394039988, -0.8274071521610402],
#   [2.3167357814924374, -1.1665406464816646],
#   [2.343698278222165, -1.153901307572685],
#   [2.3397979361347483, -1.1611641897497007],
#   [2.3398066320590276, -1.1611636361162772],
#   [2.339813793044372, -1.1611611453249862],
#   [2.3415104332243475, -1.1595400954471602],
#   [2.3415093348812226, -1.1595515695650045],
#   [2.341508913285499, -1.1592467946331202],
#   [2.3415121281326883, -1.159225980813964],
#   [2.34151400023565, -1.1592184441455737],
#   [2.34152873826012, -1.1591460100671402],
#   [2.3415329949371104, -1.1591179189235175],
#   [2.3415353321798076, -1.1591088317443807],
#   [2.341542623898521, -1.159074090359344],
# ...

# %%
sugg_obj_initial0_Mk0_ls01_amp1_EI_05_exp = get_sugg_obj_exp(locs_initial0_Mk0_ls01_amp1_EI_05_exp)
sugg_obj_initial0_Mk0_ls01_amp10_EI_05_exp = get_sugg_obj_exp(locs_initial0_Mk0_ls01_amp10_EI_05_exp)
sugg_obj_initial0_Mk0_ls05_amp1_EI_05_exp = get_sugg_obj_exp(locs_initial0_Mk0_ls05_amp1_EI_05_exp)
sugg_obj_initial0_Mk0_ls05_amp10_EI_05_exp = get_sugg_obj_exp(locs_initial0_Mk0_ls05_amp10_EI_05_exp)
sugg_obj_initial0_Mk0_ls10_amp1_EI_05_exp = get_sugg_obj_exp(locs_initial0_Mk0_ls10_amp1_EI_05_exp)
sugg_obj_initial0_Mk0_ls10_amp10_EI_05_exp = get_sugg_obj_exp(locs_initial0_Mk0_ls10_amp10_EI_05_exp)

# %%
sugg_obj_initial0_Mk0_ls01_amp1_EI_10_exp = get_sugg_obj_exp(locs_initial0_Mk0_ls01_amp1_EI_10_exp)
sugg_obj_initial0_Mk0_ls01_amp10_EI_10_exp = get_sugg_obj_exp(locs_initial0_Mk0_ls01_amp10_EI_10_exp)
sugg_obj_initial0_Mk0_ls05_amp1_EI_10_exp = get_sugg_obj_exp(locs_initial0_Mk0_ls05_amp1_EI_10_exp)
sugg_obj_initial0_Mk0_ls05_amp10_EI_10_exp = get_sugg_obj_exp(locs_initial0_Mk0_ls05_amp10_EI_10_exp)
sugg_obj_initial0_Mk0_ls10_amp1_EI_10_exp = get_sugg_obj_exp(locs_initial0_Mk0_ls10_amp1_EI_10_exp)
sugg_obj_initial0_Mk0_ls10_amp10_EI_10_exp = get_sugg_obj_exp(locs_initial0_Mk0_ls10_amp10_EI_10_exp)

# %% [markdown]
# ### Averaging values of each experiments

# %%
avg_sugg_obj_initial0_Mk0_ls01_amp1_EI_01 = np.average(sugg_obj_initial0_Mk0_ls01_amp1_EI_01_exp, axis=0)
avg_sugg_obj_initial0_Mk0_ls01_amp10_EI_01 = np.average(sugg_obj_initial0_Mk0_ls01_amp10_EI_01_exp, axis=0)
avg_sugg_obj_initial0_Mk0_ls05_amp1_EI_01 = np.average(sugg_obj_initial0_Mk0_ls05_amp1_EI_01_exp, axis=0)
avg_sugg_obj_initial0_Mk0_ls10_amp1_EI_01 = np.average(sugg_obj_initial0_Mk0_ls10_amp1_EI_01_exp, axis=0)
avg_sugg_obj_initial0_Mk0_ls10_amp10_EI_01 = np.average(sugg_obj_initial0_Mk0_ls10_amp10_EI_01_exp, axis=0)

avg_sugg_obj_initial0_Mk0_ls005_amp1_EI_01 = np.average(sugg_obj_initial0_Mk0_ls005_amp1_EI_01_exp, axis=0)
avg_sugg_obj_initial0_Mk0_ls005_amp10_EI_01 = np.average(sugg_obj_initial0_Mk0_ls005_amp10_EI_01_exp, axis=0)

# %%
sugg_obj_initial0_Mk0_ls005_amp10_EI_01_exp
# Out:
# [[-0.05229446251981912,
#   -0.2843030223654428,
#   -0.36885033021953195,
#   -0.35761639400300693,
#   -0.2321959173589757,
#   -0.07283413417981616,
#   -0.3527603530200729,
#   -0.1757502469472272,
#   -0.36508630326950653,
#   -0.36911263722439397,
#   -0.3691194813038453,
#   -0.36911932283434234,
#   -0.36911921043286894,
#   -0.3690936987940792,
#   -0.369093523912876,
#   -0.3690990606506819,
#   -0.3690993080598232,
#   -0.36909937275986304,
#   -0.36910010262594145,
#   -0.3691004329085646,
#   -0.36910050660840615,
#   -0.3691008431443225,
#   -0.6127893803614798,
#   -0.6127917031054442,
#   -0.6128981224358846,
#   -0.46973741420948684,
#   -0.3578135311234482,
#   -0.6193116058475303,
#   -0.6192298643774229,
#   -0.6194974181964067,
#   -0.6194742704689804,
#   -0.6194799660689452,
#   -0.6194797731290066,
#   -0.6194796438639626,
#   -0.6194799188299795,
#   -0.6194800292073537,
#   -0.619479827217739,
#   -0.619479957581546,
#   -0.6194801716255214,
# ...

# %%
avg_sugg_obj_initial0_Mk0_ls05_amp10_EI_01 = np.average(sugg_obj_initial0_Mk0_ls05_amp10_EI_01_exp, axis=0)

# %%
avg_sugg_obj_initial0_Mk0_ls01_amp1_EI_05 = np.average(sugg_obj_initial0_Mk0_ls01_amp1_EI_05_exp, axis=0)
avg_sugg_obj_initial0_Mk0_ls01_amp10_EI_05 = np.average(sugg_obj_initial0_Mk0_ls01_amp10_EI_05_exp, axis=0)
avg_sugg_obj_initial0_Mk0_ls05_amp1_EI_05 = np.average(sugg_obj_initial0_Mk0_ls05_amp1_EI_05_exp, axis=0)
avg_sugg_obj_initial0_Mk0_ls05_amp10_EI_05 = np.average(sugg_obj_initial0_Mk0_ls05_amp10_EI_05_exp, axis=0)
avg_sugg_obj_initial0_Mk0_ls10_amp1_EI_05 = np.average(sugg_obj_initial0_Mk0_ls10_amp1_EI_05_exp, axis=0)

# %%
avg_sugg_obj_initial0_Mk0_ls10_amp10_EI_05 = np.average(sugg_obj_initial0_Mk0_ls10_amp10_EI_05_exp, axis=0)

# %%
avg_sugg_obj_initial0_Mk0_ls01_amp1_EI_10 = np.average(sugg_obj_initial0_Mk0_ls01_amp1_EI_10_exp, axis=0)
avg_sugg_obj_initial0_Mk0_ls01_amp10_EI_10 = np.average(sugg_obj_initial0_Mk0_ls01_amp10_EI_10_exp, axis=0)
avg_sugg_obj_initial0_Mk0_ls05_amp1_EI_10 = np.average(sugg_obj_initial0_Mk0_ls05_amp1_EI_10_exp, axis=0)
avg_sugg_obj_initial0_Mk0_ls05_amp10_EI_10 = np.average(sugg_obj_initial0_Mk0_ls05_amp10_EI_10_exp, axis=0)
avg_sugg_obj_initial0_Mk0_ls10_amp1_EI_10 = np.average(sugg_obj_initial0_Mk0_ls10_amp1_EI_10_exp, axis=0)
avg_sugg_obj_initial0_Mk0_ls10_amp10_EI_10 = np.average(sugg_obj_initial0_Mk0_ls10_amp10_EI_10_exp, axis=0)

# %% [markdown]
# ### Plotting the real function value at suggested locations

# %% [markdown]
# ### EI 0.1 version, same amplitude 1.0

# %%
plt.figure(figsize=(10,7))

plt.plot(avg_sugg_obj_initial0_Mk0_ls005_amp1_EI_01, label='ls005 amp1.0')
#plt.plot(avg_sugg_obj_initial0_Mk0_ls005_amp10_EI_01, label='ls005 amp10')

plt.plot(avg_sugg_obj_initial0_Mk0_ls01_amp1_EI_01, label='ls01 amp1.0')
#plt.plot(avg_sugg_obj_initial0_Mk0_ls01_amp10_EI_01, label='ls01 amp10')

plt.plot(avg_sugg_obj_initial0_Mk0_ls05_amp1_EI_01, label='ls05 amp1.0')
#plt.plot(avg_sugg_obj_initial0_Mk0_ls05_amp10_EI_01, label='ls05 amp10')

plt.plot(avg_sugg_obj_initial0_Mk0_ls10_amp1_EI_01, label='ls10 amp1.0')
#plt.plot(avg_sugg_obj_initial0_Mk0_ls10_amp10_EI_01, label='ls10 amp10')

plt.hlines(opt_val, xmin=0, xmax=80, colors='k')
plt.legend()
plt.show()

# %% [markdown]
# ### EI 0.1 version, sample ampliture 10

# %%
plt.figure(figsize=(10,7))

#plt.plot(avg_sugg_obj_initial0_Mk0_ls005_amp1_EI_01, label='ls005 amp1.0')
plt.plot(avg_sugg_obj_initial0_Mk0_ls005_amp10_EI_01, label='ls005 amp10')

#plt.plot(avg_sugg_obj_initial0_Mk0_ls01_amp1_EI_01, label='ls01 amp1.0')
plt.plot(avg_sugg_obj_initial0_Mk0_ls01_amp10_EI_01, label='ls01 amp10')

#plt.plot(avg_sugg_obj_initial0_Mk0_ls05_amp1_EI_01, label='ls05 amp1.0')
plt.plot(avg_sugg_obj_initial0_Mk0_ls05_amp10_EI_01, label='ls05 amp10')

#plt.plot(avg_sugg_obj_initial0_Mk0_ls10_amp1_EI_01, label='ls10 amp1.0')
plt.plot(avg_sugg_obj_initial0_Mk0_ls10_amp10_EI_01, label='ls10 amp10')

plt.hlines(opt_val, xmin=0, xmax=80, colors='k')
plt.legend()
plt.show()

# %% [markdown]
# ### EI 0.5 version, same amplitude 1.0

# %%
plt.figure(figsize=(10,7))

plt.plot(avg_sugg_obj_initial0_Mk0_ls01_amp1_EI_05, label='ls01 amp1.0')
#plt.plot(avg_sugg_obj_initial0_Mk0_ls01_amp10_EI_05, label='ls01 amp10')

plt.plot(avg_sugg_obj_initial0_Mk0_ls05_amp1_EI_05, label='ls05 amp1.0')
#plt.plot(avg_sugg_obj_initial0_Mk0_ls05_amp10_EI_05, label='ls05 amp10')

plt.plot(avg_sugg_obj_initial0_Mk0_ls10_amp1_EI_05, label='ls10 amp1.0')
#plt.plot(avg_sugg_obj_initial0_Mk0_ls10_amp10_EI_05, label='ls10 amp10')

plt.hlines(opt_val, xmin=0, xmax=80, colors='k')
plt.legend()
plt.show()

# %% [markdown]
# ### EI 0.5 version, sample amplitude 10

# %%
plt.figure(figsize=(10,7))

#plt.plot(avg_sugg_obj_initial0_Mk0_ls01_amp1_EI_05, label='ls01 amp1.0')
plt.plot(avg_sugg_obj_initial0_Mk0_ls01_amp10_EI_05, label='ls01 amp10')

#plt.plot(avg_sugg_obj_initial0_Mk0_ls05_amp1_EI_05, label='ls05 amp1.0')
plt.plot(avg_sugg_obj_initial0_Mk0_ls05_amp10_EI_05, label='ls05 amp10')

#plt.plot(avg_sugg_obj_initial0_Mk0_ls10_amp1_EI_05, label='ls10 amp1.0')
plt.plot(avg_sugg_obj_initial0_Mk0_ls10_amp10_EI_05, label='ls10 amp10')

plt.hlines(opt_val, xmin=0, xmax=80, colors='k')
plt.legend()
plt.show()

# %% [markdown]
# ### EI 1.0 version, same amplitude 1.0

# %%
plt.figure(figsize=(10,7))

plt.plot(avg_sugg_obj_initial0_Mk0_ls01_amp1_EI_10, label='ls01 amp1.0')
#plt.plot(avg_sugg_obj_initial0_Mk0_ls01_amp10_EI_10, label='ls01 amp10')

plt.plot(avg_sugg_obj_initial0_Mk0_ls05_amp1_EI_10, label='ls05 amp1.0')
#plt.plot(avg_sugg_obj_initial0_Mk0_ls05_amp10_EI_10, label='ls05 amp10')

plt.plot(avg_sugg_obj_initial0_Mk0_ls10_amp1_EI_10, label='ls10 amp1.0')
#plt.plot(avg_sugg_obj_initial0_Mk0_ls10_amp10_EI_10, label='ls10 amp10')

plt.hlines(opt_val, xmin=0, xmax=80, colors='k')
plt.legend()
plt.show()

# %% [markdown]
# ### EI 1.0 version, same amplitude 10

# %%
plt.figure(figsize=(10,7))

#plt.plot(avg_sugg_obj_initial0_Mk0_ls01_amp1_EI_10, label='ls01 amp1.0')
plt.plot(avg_sugg_obj_initial0_Mk0_ls01_amp10_EI_10, label='ls01 amp10')

#plt.plot(avg_sugg_obj_initial0_Mk0_ls05_amp1_EI_10, label='ls05 amp1.0')
plt.plot(avg_sugg_obj_initial0_Mk0_ls05_amp10_EI_10, label='ls05 amp10')

#plt.plot(avg_sugg_obj_initial0_Mk0_ls10_amp1_EI_10, label='ls10 amp1.0')
plt.plot(avg_sugg_obj_initial0_Mk0_ls10_amp10_EI_10, label='ls10 amp10')

plt.hlines(opt_val, xmin=0, xmax=80, colors='k')
plt.legend()
plt.show()

# %% [markdown]
# ### ls01, amplitude 1.0, varying EI parameter

# %%
plt.figure(figsize=(10,7))

plt.plot(avg_sugg_obj_initial0_Mk0_ls01_amp1_EI_01, label='ls01 amp1.0, xi0.1')


plt.plot(avg_sugg_obj_initial0_Mk0_ls01_amp1_EI_05, label='ls01 amp1.0, xi0.5')


plt.plot(avg_sugg_obj_initial0_Mk0_ls01_amp1_EI_10, label='ls01 amp1.0, xi1.0')


plt.hlines(opt_val, xmin=0, xmax=80, colors='k')
plt.legend()
plt.show()

# %% [markdown]
# ### ls01, amplitude 10, varying EI parameter

# %%
plt.figure(figsize=(10,7))

plt.plot(avg_sugg_obj_initial0_Mk0_ls01_amp10_EI_01, label='ls01 amp10, xi0.1')
plt.plot(avg_sugg_obj_initial0_Mk0_ls01_amp10_EI_05, label='ls01 amp10, xi0.5')
plt.plot(avg_sugg_obj_initial0_Mk0_ls01_amp10_EI_10, label='ls01 amp10, xi1.0')

plt.hlines(opt_val, xmin=0, xmax=80, colors='k')
plt.legend()
plt.show()

# %% [markdown]
# ### ls05, amplitude 1, varying EI parameter

# %%
plt.figure(figsize=(10,7))

plt.plot(avg_sugg_obj_initial0_Mk0_ls05_amp1_EI_01, label='ls05 amp1.0, xi0.1')
plt.plot(avg_sugg_obj_initial0_Mk0_ls05_amp1_EI_05, label='ls05 amp1.0, xi0.5')
plt.plot(avg_sugg_obj_initial0_Mk0_ls05_amp1_EI_10, label='ls05 amp1.0, xi1.0')


plt.hlines(opt_val, xmin=0, xmax=80, colors='k')
plt.legend()
plt.show()

# %% [markdown]
# ### ls05, amplitude 10, varying EI parameter

# %%
plt.figure(figsize=(10,7))

plt.plot(avg_sugg_obj_initial0_Mk0_ls05_amp10_EI_01, label='ls05 amp10, xi0.1')
plt.plot(avg_sugg_obj_initial0_Mk0_ls05_amp10_EI_05, label='ls05 amp10, xi0.5')
plt.plot(avg_sugg_obj_initial0_Mk0_ls05_amp10_EI_10, label='ls05 amp10, xi1.0')

plt.hlines(opt_val, xmin=0, xmax=80, colors='k')
plt.legend()
plt.show()

# %% [markdown]
# ### ls10, amplitude 1.0, varying EI parameter

# %%
plt.figure(figsize=(10,7))

plt.plot(avg_sugg_obj_initial0_Mk0_ls10_amp1_EI_01, label='ls10 amp1.0, xi0.1')
plt.plot(avg_sugg_obj_initial0_Mk0_ls10_amp1_EI_05, label='ls10 amp1.0, xi0.5')
plt.plot(avg_sugg_obj_initial0_Mk0_ls10_amp1_EI_10, label='ls10 amp1.0, xi1.0')


plt.hlines(opt_val, xmin=0, xmax=80, colors='k')
plt.legend()
plt.show()

# %% [markdown]
# ### ls10, amplitude 10, varying EI parameter

# %%
plt.figure(figsize=(10,7))

plt.plot(avg_sugg_obj_initial0_Mk0_ls10_amp10_EI_01, label='ls10 amp10, xi0.1')
plt.plot(avg_sugg_obj_initial0_Mk0_ls10_amp10_EI_05, label='ls10 amp10, xi0.5')
plt.plot(avg_sugg_obj_initial0_Mk0_ls10_amp10_EI_10, label='ls10 amp10, xi1.0')

plt.hlines(opt_val, xmin=0, xmax=80, colors='k')
plt.legend()
plt.show()
