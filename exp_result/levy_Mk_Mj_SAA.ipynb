# %%
import pymongo
from spearmint.utils import compression
from spearmint.utils import functions
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from spearmint.tasks import input_space
sns.set()

# %% [markdown]
# ### Connecting MongoDB server

# %%
mongo_conn = pymongo.MongoClient('127.0.0.1',27017)
mongo_conn.list_database_names()
# Out:
# [u'admin', u'config', u'local', u'spearmint']

# %%
mongo_db = mongo_conn['spearmint']

# %% [markdown]
# ### Loading document from database

# %%
collection_list = mongo_db.list_collection_names()

# %%
jobs_initial5_Mk200_Mj1_exp = []
jobs_initial5_Mk50_Mj1_v2_exp = []
jobs_initial5_Mk200_Mj1_v2_exp = []
jobs_initial5_Mk200_Mj1_v3_exp = []
jobs_initial5_Mk10_Mj1_exp = []
jobs_initial5_Mk10_Mj1_v2_exp = []
jobs_initial5_Mk50_Mj1_exp = []
jobs_initial5_Mk100_Mj1_exp = []
jobs_initial5_Mk300_Mj1_exp = []

jobs_initial5_Mk5_Mj1_saa_exp = []
jobs_initial5_Mk5_Mj1_saa_5seq_exp = []
jobs_initial5_Mk5_Mj1_saa_5seq_10N_exp = []
jobs_Mk10_Mj1_exp = []
jobs_Mk200_Mj1_exp = []

jobs_saa_test_exp = []
jobs_saa_test_v2_exp = []
jobs_saa_test_v3_exp = []

jobs_saa_N5_seq5 = []

jobs_saa_origin_exp = []

jobs_saa_cumulative_exp = []
jobs_saa_cumulative_exp_2 = []
jobs_saa_cumulative_exp_3 = []
jobs_saa_cumulative_exp_4 = []
jobs_saa_cumulative_exp_5 = []
jobs_saa_cumulative_multi_exp = []

jobs_multi_start_20_exp = []
jobs_toler_minus_5_exp = []


recomm_initial5_Mk200_Mj1_exp = []
recomm_initial5_Mk50_Mj1_v2_exp = []
recomm_initial5_Mk200_Mj1_v2_exp = []
recomm_initial5_Mk200_Mj1_v3_exp = []
recomm_initial5_Mk10_Mj1_exp = []
recomm_initial5_Mk10_Mj1_v2_exp = []
recomm_initial5_Mk50_Mj1_exp = []
recomm_initial5_Mk100_Mj1_exp = []
recomm_initial5_Mk300_Mj1_exp = []


recomm_initial5_Mk5_Mj1_saa_exp = []
recomm_initial5_Mk5_Mj1_saa_5seq_exp = []
recomm_initial5_Mk5_Mj1_saa_5seq_10N_exp = []
recomm_Mk10_Mj1_exp = []
recomm_Mk200_Mj1_exp = []

recomm_saa_test_exp = []
recomm_saa_test_v2_exp = []
recomm_saa_test_v3_exp = []

recomm_saa_N5_seq5 = []

recomm_saa_origin_exp = []

recomm_saa_cumulative_exp = []
recomm_saa_cumulative_exp_2 = []
recomm_saa_cumulative_exp_3 = []
recomm_saa_cumulative_exp_4 = []
recomm_saa_cumulative_exp_5 = []
recomm_saa_cumulative_multi_exp = []

recomm_multi_start_20_exp = []
recomm_toler_minus_5_exp = []

for i in range(25):
    jobs_initial5_Mk200_Mj1_exp.append(mongo_db["levy_initial-%d.jobs"%i])
    jobs_Mk10_Mj1_exp.append(mongo_db["levy_4-%d.jobs"%i])
    jobs_Mk200_Mj1_exp.append(mongo_db["levy_12-%d.jobs"%i])
    if "levy_initial5_Mk10_Mj1-%d.jobs"%i in collection_list: jobs_initial5_Mk10_Mj1_exp.append(mongo_db["levy_initial5_Mk10_Mj1-%d.jobs"%i])
    if "levy_initial5_Mk10_Mj1_ver2-%d.jobs"%i in collection_list: jobs_initial5_Mk10_Mj1_v2_exp.append(mongo_db["levy_initial5_Mk10_Mj1_ver2-%d.jobs"%i])
    if "levy_initial5_Mk50_Mj1-%d.jobs"%i in collection_list: jobs_initial5_Mk50_Mj1_exp.append(mongo_db["levy_initial5_Mk50_Mj1-%d.jobs"%i])
    if "levy_initial5_Mk100_Mj1-%d.jobs"%i in collection_list: jobs_initial5_Mk100_Mj1_exp.append(mongo_db["levy_initial5_Mk100_Mj1-%d.jobs"%i])
    if "levy_initial5_Mk50_Mj1_ver2-%d.jobs"%i in collection_list: jobs_initial5_Mk50_Mj1_v2_exp.append(mongo_db["levy_initial5_Mk50_Mj1_ver2-%d.jobs"%i])
    if "levy_initial5_Mk200_Mj1_ver2-%d.jobs"%i in collection_list: jobs_initial5_Mk200_Mj1_v2_exp.append(mongo_db["levy_initial5_Mk200_Mj1_ver2-%d.jobs"%i])
    if "levy_initial5_Mk200_Mj1_ver3-%d.jobs"%i in collection_list: jobs_initial5_Mk200_Mj1_v3_exp.append(mongo_db["levy_initial5_Mk200_Mj1_ver3-%d.jobs"%i])
    if "levy_initial5_Mk300_Mj1-%d.jobs"%i in collection_list: jobs_initial5_Mk300_Mj1_exp.append(mongo_db["levy_initial5_Mk300_Mj1-%d.jobs"%i])
    if "levy_initial5_Mk5_Mj1_saa-%d.jobs"%i in collection_list: jobs_initial5_Mk5_Mj1_saa_exp.append(mongo_db["levy_initial5_Mk5_Mj1_saa-%d.jobs"%i])
    if "levy_initial5_Mk5_Mj1_saa_5seq-%d.jobs"%i in collection_list: jobs_initial5_Mk5_Mj1_saa_5seq_exp.append(mongo_db["levy_initial5_Mk5_Mj1_saa_5seq-%d.jobs"%i])
    if "levy_initial5_Mk5_Mj1_saa_5seq_10N-%d.jobs"%i in collection_list: jobs_initial5_Mk5_Mj1_saa_5seq_10N_exp.append(mongo_db["levy_initial5_Mk5_Mj1_saa_5seq_10N-%d.jobs"%i])
    if "levy_saa_test-%d.jobs"%i in collection_list: jobs_saa_test_exp.append(mongo_db["levy_saa_test-%d.jobs"%i])
    if "levy_saa_test_ver2-%d.jobs"%i in collection_list: jobs_saa_test_v2_exp.append(mongo_db["levy_saa_test_ver2-%d.jobs"%i])
    if "levy_saa_test_ver3-%d.jobs"%i in collection_list: jobs_saa_test_v3_exp.append(mongo_db["levy_saa_test_ver3-%d.jobs"%i])
    if "levy_saa_N5_seq5-%d.jobs"%i in collection_list: jobs_saa_N5_seq5.append(mongo_db["levy_saa_N5_seq5-%d.jobs"%i])
    if "levy_saa_origin-%d.jobs"%i in collection_list: jobs_saa_origin_exp.append(mongo_db["levy_saa_origin-%d.jobs"%i])
    if "levy_cumulative_saa_test-%d.jobs"%i in collection_list: jobs_saa_cumulative_exp.append(mongo_db["levy_cumulative_saa_test-%d.jobs"%i])
    if "levy_cumulative_saa_test_2-%d.jobs"%i in collection_list: jobs_saa_cumulative_exp_2.append(mongo_db["levy_cumulative_saa_test_2-%d.jobs"%i])
    if "levy_cumulative_saa_test_3-%d.jobs"%i in collection_list: jobs_saa_cumulative_exp_3.append(mongo_db["levy_cumulative_saa_test_3-%d.jobs"%i])
    if "levy_cumulative_saa_test_4-%d.jobs"%i in collection_list: jobs_saa_cumulative_exp_4.append(mongo_db["levy_cumulative_saa_test_4-%d.jobs"%i])
    if "levy_cumulative_saa_test_5-%d.jobs"%i in collection_list: jobs_saa_cumulative_exp_5.append(mongo_db["levy_cumulative_saa_test_5-%d.jobs"%i])
    if "levy_cumulative_saa_multi_test-%d.jobs"%i in collection_list: jobs_saa_cumulative_multi_exp.append(mongo_db["levy_cumulative_saa_multi_test-%d.jobs"%i])
    if "levy_for_multi_start-%d.jobs"%i in collection_list: jobs_multi_start_20_exp.append(mongo_db["levy_for_multi_start-%d.jobs"%i])
    if "levy_vanilla_toler_minus_5-%d.jobs"%i in collection_list: jobs_toler_minus_5_exp.append(mongo_db["levy_vanilla_toler_minus_5-%d.jobs"%i])
    
        
    recomm_initial5_Mk200_Mj1_exp.append(mongo_db["levy_initial-%d.recommendations"%i])
    recomm_Mk10_Mj1_exp.append(mongo_db["levy_4-%d.recommendations"%i])
    recomm_Mk200_Mj1_exp.append(mongo_db["levy_12-%d.recommendations"%i])
    if "levy_initial5_Mk10_Mj1-%d.recommendations"%i in collection_list: recomm_initial5_Mk10_Mj1_exp.append(mongo_db["levy_initial5_Mk10_Mj1-%d.recommendations"%i])
    if "levy_initial5_Mk10_Mj1_ver2-%d.recommendations"%i in collection_list: recomm_initial5_Mk10_Mj1_v2_exp.append(mongo_db["levy_initial5_Mk10_Mj1_ver2-%d.recommendations"%i])
    if "levy_initial5_Mk50_Mj1-%d.recommendations"%i in collection_list: recomm_initial5_Mk50_Mj1_exp.append(mongo_db["levy_initial5_Mk50_Mj1-%d.recommendations"%i])
    if "levy_initial5_Mk100_Mj1-%d.recommendations"%i in collection_list: recomm_initial5_Mk100_Mj1_exp.append(mongo_db["levy_initial5_Mk100_Mj1-%d.recommendations"%i])
    if "levy_initial5_Mk50_Mj1_ver2-%d.recommendations"%i in collection_list: recomm_initial5_Mk50_Mj1_v2_exp.append(mongo_db["levy_initial5_Mk50_Mj1_ver2-%d.recommendations"%i])
    if "levy_initial5_Mk200_Mj1_ver2-%d.recommendations"%i in collection_list: recomm_initial5_Mk200_Mj1_v2_exp.append(mongo_db["levy_initial5_Mk200_Mj1_ver2-%d.recommendations"%i])
    if "levy_initial5_Mk200_Mj1_ver3-%d.recommendations"%i in collection_list: recomm_initial5_Mk200_Mj1_v3_exp.append(mongo_db["levy_initial5_Mk200_Mj1_ver3-%d.recommendations"%i])
    if "levy_initial5_Mk300_Mj1-%d.recommendations"%i in collection_list: recomm_initial5_Mk300_Mj1_exp.append(mongo_db["levy_initial5_Mk300_Mj1-%d.recommendations"%i])
    if "levy_initial5_Mk5_Mj1_saa-%d.recommendations"%i in collection_list: recomm_initial5_Mk5_Mj1_saa_exp.append(mongo_db["levy_initial5_Mk5_Mj1_saa-%d.recommendations"%i])
    if "levy_initial5_Mk5_Mj1_saa_5seq-%d.recommendations"%i in collection_list: recomm_initial5_Mk5_Mj1_saa_5seq_exp.append(mongo_db["levy_initial5_Mk5_Mj1_saa_5seq-%d.recommendations"%i])
    if "levy_initial5_Mk5_Mj1_saa_5seq_10N-%d.recommendations"%i in collection_list: recomm_initial5_Mk5_Mj1_saa_5seq_10N_exp.append(mongo_db["levy_initial5_Mk5_Mj1_saa_5seq_10N-%d.recommendations"%i])
    if "levy_saa_test-%d.recommendations"%i in collection_list: recomm_saa_test_exp.append(mongo_db["levy_saa_test-%d.recommendations"%i])
    if "levy_saa_test_ver2-%d.recommendations"%i in collection_list: recomm_saa_test_v2_exp.append(mongo_db["levy_saa_test_ver2-%d.recommendations"%i])
    if "levy_saa_test_ver3-%d.recommendations"%i in collection_list: recomm_saa_test_v3_exp.append(mongo_db["levy_saa_test_ver3-%d.recommendations"%i])
    if "levy_saa_N5_seq5-%d.recommendations"%i in collection_list: recomm_saa_N5_seq5.append(mongo_db["levy_saa_N5_seq5-%d.recommendations"%i])
    if "levy_saa_origin-%d.recommendations"%i in collection_list: recomm_saa_origin_exp.append(mongo_db["levy_saa_origin-%d.recommendations"%i])
    if "levy_cumulative_saa_test-%d.recommendations"%i in collection_list: recomm_saa_cumulative_exp.append(mongo_db["levy_cumulative_saa_test-%d.recommendations"%i])
    if "levy_cumulative_saa_test_2-%d.recommendations"%i in collection_list: recomm_saa_cumulative_exp_2.append(mongo_db["levy_cumulative_saa_test_2-%d.recommendations"%i])
    if "levy_cumulative_saa_test_3-%d.recommendations"%i in collection_list: recomm_saa_cumulative_exp_3.append(mongo_db["levy_cumulative_saa_test_3-%d.recommendations"%i])
    if "levy_cumulative_saa_test_4-%d.recommendations"%i in collection_list: recomm_saa_cumulative_exp_4.append(mongo_db["levy_cumulative_saa_test_4-%d.recommendations"%i])
    if "levy_cumulative_saa_test_5-%d.recommendations"%i in collection_list: recomm_saa_cumulative_exp_5.append(mongo_db["levy_cumulative_saa_test_5-%d.recommendations"%i])
    if "levy_cumulative_saa_multi_test-%d.recommendations"%i in collection_list: recomm_saa_cumulative_multi_exp.append(mongo_db["levy_cumulative_saa_multi_test-%d.recommendations"%i])
    if "levy_for_multi_start-%d.recommendations"%i in collection_list: recomm_multi_start_20_exp.append(mongo_db["levy_for_multi_start-%d.recommendations"%i])
    if "levy_vanilla_toler_minus_5-%d.recommendations"%i in collection_list: recomm_toler_minus_5_exp.append(mongo_db["levy_vanilla_toler_minus_5-%d.recommendations"%i])

# %% [markdown]
# ### get_objective method gets the predicted optimal value in GP model

# %%
Mk200_Mj1_objs = functions.get_objective(recomm_Mk200_Mj1_exp)
Mk10_Mj1_objs = functions.get_objective(recomm_Mk10_Mj1_exp)


initial5_Mk200_Mj1_objs = functions.get_objective(recomm_initial5_Mk200_Mj1_exp)
initial5_Mk200_Mj1_v2_objs = functions.get_objective(recomm_initial5_Mk200_Mj1_v2_exp)
initial5_Mk200_Mj1_v3_objs = functions.get_objective(recomm_initial5_Mk200_Mj1_v3_exp)
initial5_Mk300_Mj1_objs = functions.get_objective(recomm_initial5_Mk300_Mj1_exp)
initial5_Mk50_Mj1_v2_objs = functions.get_objective(recomm_initial5_Mk50_Mj1_v2_exp)
initial5_Mk10_Mj1_objs = functions.get_objective(recomm_initial5_Mk10_Mj1_exp)
initial5_Mk10_Mj1_v2_objs = functions.get_objective(recomm_initial5_Mk10_Mj1_v2_exp)
initial5_Mk50_Mj1_objs = functions.get_objective(recomm_initial5_Mk50_Mj1_exp)
initial5_Mk10Mj1_objs = functions.get_objective(recomm_initial5_Mk100_Mj1_exp)
initial5_Mk200_Mj1_saa_objs = functions.get_objective(recomm_initial5_Mk5_Mj1_saa_exp)
initial5_Mk200_Mj1_saa_5seq_objs = functions.get_objective(recomm_initial5_Mk5_Mj1_saa_5seq_exp)
initial5_Mk200_Mj1_saa_5seq_10N_objs = functions.get_objective(recomm_initial5_Mk5_Mj1_saa_5seq_10N_exp)

saa_test_objs = functions.get_objective(recomm_saa_test_exp)
saa_test_v2_objs = functions.get_objective(recomm_saa_test_v2_exp)
saa_test_v3_objs = functions.get_objective(recomm_saa_test_v3_exp)

saa_N5_seq5 = functions.get_objective(recomm_saa_N5_seq5)

saa_origin = functions.get_objective(recomm_saa_origin_exp)

saa_cumulative = functions.get_objective(recomm_saa_cumulative_exp)
saa_cumulative_2 = functions.get_objective(recomm_saa_cumulative_exp_2)
saa_cumulative_3 = functions.get_objective(recomm_saa_cumulative_exp_3)
saa_cumulative_4 = functions.get_objective(recomm_saa_cumulative_exp_4)
saa_cumulative_multi = functions.get_objective(recomm_saa_cumulative_multi_exp)

multi_start_20 = functions.get_objective(recomm_multi_start_20_exp)
vanilla_toler_minus_5 = functions.get_objective(recomm_toler_minus_5_exp)

# %%
locs_Mk200_Mj1_exp = functions.get_recomm_loc(recomm_Mk200_Mj1_exp)
locs_Mk10_Mj1_exp = functions.get_recomm_loc(recomm_Mk10_Mj1_exp)

locs_initial5_Mk200_Mj1_exp = functions.get_recomm_loc(recomm_initial5_Mk200_Mj1_exp)
locs_initial5_Mk50_Mj1_v2_exp = functions.get_recomm_loc(recomm_initial5_Mk50_Mj1_v2_exp)
locs_initial5_Mk200_Mj1_v2_exp = functions.get_recomm_loc(recomm_initial5_Mk200_Mj1_v2_exp)
locs_initial5_Mk200_Mj1_v3_exp = functions.get_recomm_loc(recomm_initial5_Mk200_Mj1_v3_exp)
locs_initial5_Mk300_Mj1_exp = functions.get_recomm_loc(recomm_initial5_Mk300_Mj1_exp)
locs_initial5_Mk100_Mj1_exp = functions.get_recomm_loc(recomm_initial5_Mk100_Mj1_exp)
locs_initial5_Mk10_Mj1_exp = functions.get_recomm_loc(recomm_initial5_Mk10_Mj1_exp)
locs_initial5_Mk10_Mj1_v2_exp = functions.get_recomm_loc(recomm_initial5_Mk10_Mj1_v2_exp)
locs_initial5_Mk50_Mj1_exp = functions.get_recomm_loc(recomm_initial5_Mk50_Mj1_exp)
locs_initial5_Mk200_Mj1_saa_exp = functions.get_recomm_loc(recomm_initial5_Mk5_Mj1_saa_exp)
locs_initial5_Mk200_Mj1_saa_5seq_exp = functions.get_recomm_loc(recomm_initial5_Mk5_Mj1_saa_5seq_exp)
locs_initial5_Mk200_Mj1_saa_5seq_10N_exp = functions.get_recomm_loc(recomm_initial5_Mk5_Mj1_saa_5seq_10N_exp)

locs_saa_test_exp = functions.get_recomm_loc(recomm_saa_test_exp)
locs_saa_test_v2_exp = functions.get_recomm_loc(recomm_saa_test_v2_exp)
locs_saa_test_v3_exp = functions.get_recomm_loc(recomm_saa_test_v3_exp)

locs_saa_N5_seq5_exp = functions.get_recomm_loc(recomm_saa_N5_seq5)

locs_saa_origin_exp = functions.get_recomm_loc(recomm_saa_origin_exp)

locs_saa_cumulative_exp = functions.get_recomm_loc(recomm_saa_cumulative_exp)
locs_saa_cumulative_exp_2 = functions.get_recomm_loc(recomm_saa_cumulative_exp_2)
locs_saa_cumulative_exp_3 = functions.get_recomm_loc(recomm_saa_cumulative_exp_3)
locs_saa_cumulative_exp_4 = functions.get_recomm_loc(recomm_saa_cumulative_exp_4)
locs_saa_cumulative_multi_exp = functions.get_recomm_loc(recomm_saa_cumulative_multi_exp)

locs_multi_start_20_exp = functions.get_recomm_loc(recomm_multi_start_20_exp)
locs_vanilla_toler_minus_5_exp = functions.get_recomm_loc(recomm_toler_minus_5_exp)

# %%
minimum = 35
for exp in locs_saa_origin_exp:
    minimum = minimum if len(exp) > minimum else len(exp)
    
locs_saa_origin_exp = [list_[:minimum] for list_ in locs_saa_origin_exp]

minimum = 35
for exp in locs_saa_cumulative_exp:
    minimum = minimum if len(exp) > minimum else len(exp)
    
locs_saa_cumulative_exp = [list_[:minimum] for list_ in locs_saa_cumulative_exp]

minimum = 35
for exp in locs_saa_cumulative_exp_4:
    minimum = minimum if len(exp) > minimum else len(exp)
    
locs_saa_cumulative_exp_4 = [list_[:minimum] for list_ in locs_saa_cumulative_exp_4]


minimum = 35
for exp in locs_saa_cumulative_multi_exp:
    minimum = minimum if len(exp) > minimum else len(exp)
    
locs_saa_cumulative_multi_exp = [list_[:minimum] for list_ in locs_saa_cumulative_multi_exp]

# %%
locs_saa_test_exp = [list_[:11] for list_ in locs_saa_test_exp]
locs_saa_test_v2_exp = [list_[:12] for list_ in locs_saa_test_v2_exp]

# %%
locs_initial5_Mk200_Mj1_exp = [list_[:30] for list_ in locs_initial5_Mk200_Mj1_exp]
locs_initial5_Mk200_Mj1_v2_exp = [list_[:14] for list_ in locs_initial5_Mk200_Mj1_v2_exp]
locs_initial5_Mk50_Mj1_v2_exp = [list_[:27] for list_ in locs_initial5_Mk50_Mj1_v2_exp]

# %%
locs_initial5_Mk50_Mj1_exp = [list_[:41] for list_ in locs_initial5_Mk50_Mj1_exp]

# %%
locs_initial5_Mk200_Mj1_saa_5seq_exp = [list_[:13] for list_ in locs_initial5_Mk200_Mj1_saa_5seq_exp]
locs_initial5_Mk200_Mj1_saa_5seq_10N_exp = [list_[:19] for list_ in locs_initial5_Mk200_Mj1_saa_5seq_10N_exp]

# %% [markdown]
# ### Getting immediate Regret IR measure

# %%
def levy_4d(x1,x2,x3,x4):
	w1 = 1 + (x1-1)/4
	w2 = 1 + (x2-1)/4
	w3 = 1 + (x3-1)/4
	w4 = 1 + (x4-1)/4

	a = np.sin(np.pi * w1)**2
	b = ((w1-1)**2)*(1+10*(np.sin(np.pi*w1+1)**2)) + ((w2-1)**2)*(1+10*(np.sin(np.pi*w2+1)**2)) + ((w3-1)**2)*(1+10*(np.sin(np.pi*w3+1)**2)) 
	c = ((w4-1)**2) * (1 + (np.sin(2*np.pi*w4)**2))

	result = a + b + c

	return result

# %%
opt_val = 0

# %%
def get_sugg_obj_exp(locs_exp):
    obj_exp = []
    for exp_num in range(len(locs_exp)):
        objs_iter = []
        locs_cur_exp = locs_exp[exp_num]
        
        for idx in range(len(locs_exp[exp_num])):
            objs_iter.append(levy_4d(*locs_cur_exp[idx]))
            
        obj_exp.append(objs_iter)
        
    return obj_exp

# %%
def log_ir(input_list):
    return np.log10(np.abs(opt_val - levy_4d(*input_list)))

# %%
def get_irs_whole_exp(locs_exp):
    irs_exp = []
    for exp_num in range(len(locs_exp)):
        irs_iter = []
        locs_cur_exp = locs_exp[exp_num]
        
        for idx in range(len(locs_exp[0])):
            
            irs_iter.append(log_ir(locs_cur_exp[idx]))
            
        irs_exp.append(irs_iter)
        
    return irs_exp

# %%
def get_avg_irs(irs_exp):
    avg_irs = []
    for iter_num in range(len(irs_exp[0])):
        cur_iter_irs = []
        for exp_num in range(len(irs_exp)):
            cur_iter_irs.append(irs_exp[exp_num][iter_num])
            
        avg_irs.append(np.average(cur_iter_irs))
        
    return avg_irs

# %%
def get_median_irs(irs_exp):
    median_irs = []
    for iter_num in range(len(irs_exp[0])):
        cur_iter_irs = []
        for exp_num in range(len(irs_exp)):
            cur_iter_irs.append(irs_exp[exp_num][iter_num])
        
        median_irs.append(np.median(cur_iter_irs))
        
    return median_irs

# %% [markdown]
# ### Getting the "real" value of functions at suggested locations

# %%
sugg_obj_Mk200_Mj1_exp = get_sugg_obj_exp(locs_Mk200_Mj1_exp)
sugg_obj_Mk10_Mj1_exp = get_sugg_obj_exp(locs_Mk10_Mj1_exp)

sugg_obj_initial5_Mk200_Mj1_exp = get_sugg_obj_exp(locs_initial5_Mk200_Mj1_exp)
sugg_obj_initial5_Mk200_Mj1_v2_exp = get_sugg_obj_exp(locs_initial5_Mk200_Mj1_v2_exp)
sugg_obj_initial5_Mk200_Mj1_v3_exp = get_sugg_obj_exp(locs_initial5_Mk200_Mj1_v3_exp)
sugg_obj_initial5_Mk300_Mj1_exp = get_sugg_obj_exp(locs_initial5_Mk300_Mj1_exp)
sugg_obj_initial5_Mk50_Mj1_v2_exp = get_sugg_obj_exp(locs_initial5_Mk50_Mj1_v2_exp)
sugg_obj_initial5_Mk100_Mj1_exp = get_sugg_obj_exp(locs_initial5_Mk100_Mj1_exp)
sugg_obj_initial5_Mk10_Mj1_exp = get_sugg_obj_exp(locs_initial5_Mk10_Mj1_exp)
sugg_obj_initial5_Mk10_Mj1_v2_exp = get_sugg_obj_exp(locs_initial5_Mk10_Mj1_v2_exp)
sugg_obj_initial5_Mk50_Mj1_exp = get_sugg_obj_exp(locs_initial5_Mk50_Mj1_exp)
sugg_obj_initial5_Mk200_Mj1_saa_exp = get_sugg_obj_exp(locs_initial5_Mk200_Mj1_saa_exp)
sugg_obj_initial5_Mk200_Mj1_saa_5seq_exp = get_sugg_obj_exp(locs_initial5_Mk200_Mj1_saa_5seq_exp)
sugg_obj_initial5_Mk200_Mj1_saa_5seq_10N_exp = get_sugg_obj_exp(locs_initial5_Mk200_Mj1_saa_5seq_10N_exp)

sugg_obj_saa_test_exp = get_sugg_obj_exp(locs_saa_test_exp)
sugg_obj_saa_test_v2_exp = get_sugg_obj_exp(locs_saa_test_v2_exp)
sugg_obj_saa_test_v3_exp = get_sugg_obj_exp(locs_saa_test_v3_exp)

sugg_obj_saa_N5_seq5_exp = get_sugg_obj_exp(locs_saa_N5_seq5_exp)

sugg_obj_saa_origin_exp = get_sugg_obj_exp(locs_saa_origin_exp)

sugg_obj_saa_cumulative_exp = get_sugg_obj_exp(locs_saa_cumulative_exp)
sugg_obj_saa_cumulative_exp_2 = get_sugg_obj_exp(locs_saa_cumulative_exp_2)
sugg_obj_saa_cumulative_exp_3 = get_sugg_obj_exp(locs_saa_cumulative_exp_3)
sugg_obj_saa_cumulative_exp_4 = get_sugg_obj_exp(locs_saa_cumulative_exp_4)

sugg_obj_saa_cumulative_multi_exp = get_sugg_obj_exp(locs_saa_cumulative_multi_exp)

sugg_obj_multi_start_20_exp = get_sugg_obj_exp(locs_multi_start_20_exp)
sugg_obj_vanilla_toler_minus_5_exp = get_sugg_obj_exp(locs_vanilla_toler_minus_5_exp)

# %% [markdown]
# #### averaging values of each experiments

# %%
avg_sugg_obj_Mk200_Mj1 = np.average(sugg_obj_Mk200_Mj1_exp, axis=0)
avg_sugg_obj_Mk10_Mj1 = np.average(sugg_obj_Mk10_Mj1_exp, axis=0)

avg_sugg_obj_initial5_Mk200_Mj1 = np.average(sugg_obj_initial5_Mk200_Mj1_exp, axis=0)
avg_sugg_obj_initial5_Mk200_Mj1_v2 = np.average(sugg_obj_initial5_Mk200_Mj1_v2_exp, axis=0)
avg_sugg_obj_initial5_Mk200_Mj1_v3 = np.average(sugg_obj_initial5_Mk200_Mj1_v3_exp, axis=0)
avg_sugg_obj_initial5_Mk300_Mj1 = np.average(sugg_obj_initial5_Mk300_Mj1_exp, axis=0)
avg_sugg_obj_initial5_Mk50_Mj1_v2 = np.average(sugg_obj_initial5_Mk50_Mj1_v2_exp, axis=0)
avg_sugg_obj_initial5_Mk100_Mj1 = np.average(sugg_obj_initial5_Mk100_Mj1_exp, axis=0)
avg_sugg_obj_initial5_Mk10_Mj1 = np.average(sugg_obj_initial5_Mk10_Mj1_exp, axis=0)
avg_sugg_obj_initial5_Mk10_Mj1_v2 = np.average(sugg_obj_initial5_Mk10_Mj1_v2_exp, axis=0)
avg_sugg_obj_initial5_Mk50_Mj1 = np.average(sugg_obj_initial5_Mk50_Mj1_exp, axis=0)
avg_sugg_obj_initial5_Mk200_Mj1_saa = np.average(sugg_obj_initial5_Mk200_Mj1_saa_exp, axis=0)
avg_sugg_obj_initial5_Mk200_Mj1_saa_5seq = np.average(sugg_obj_initial5_Mk200_Mj1_saa_5seq_exp, axis=0)
avg_sugg_obj_initial5_Mk200_Mj1_saa_5seq_10N = np.average(sugg_obj_initial5_Mk200_Mj1_saa_5seq_10N_exp, axis=0)

avg_sugg_obj_saa_test = np.average(sugg_obj_saa_test_exp, axis=0)
avg_sugg_obj_saa_v2_test = np.average(sugg_obj_saa_test_v2_exp, axis=0)
avg_sugg_obj_saa_v3_test = np.average(sugg_obj_saa_test_v3_exp, axis=0)

avg_sugg_obj_saa_N5_seq5 = np.average(sugg_obj_saa_N5_seq5_exp, axis=0)

avg_sugg_obj_saa_origin = np.average(sugg_obj_saa_origin_exp, axis=0)

avg_sugg_obj_saa_cumulative = np.average(sugg_obj_saa_cumulative_exp, axis=0)
avg_sugg_obj_saa_cumulative_2 = np.average(sugg_obj_saa_cumulative_exp_2, axis=0)
avg_sugg_obj_saa_cumulative_3 = np.average(sugg_obj_saa_cumulative_exp_3, axis=0)
avg_sugg_obj_saa_cumulative_4 = np.average(sugg_obj_saa_cumulative_exp_4, axis=0)

avg_sugg_obj_saa_cumulative_multi = np.average(sugg_obj_saa_cumulative_multi_exp, axis=0)

avg_sugg_obj_multi_start_20 = np.average(sugg_obj_multi_start_20_exp, axis=0)

avg_sugg_obj_vanilla_toler_minus_5 = np.average(sugg_obj_vanilla_toler_minus_5_exp, axis=0)

# %% [markdown]
# ### Getting IR values for look optimization performances

# %%
irs_Mk200_Mj1_exp = get_irs_whole_exp(locs_Mk200_Mj1_exp)
irs_Mk10_Mj1_exp = get_irs_whole_exp(locs_Mk10_Mj1_exp)

irs_initial5_Mk200_Mj1_exp = get_irs_whole_exp(locs_initial5_Mk200_Mj1_exp)
irs_initial5_Mk200_Mj1_v2_exp = get_irs_whole_exp(locs_initial5_Mk200_Mj1_v2_exp)
irs_initial5_Mk200_Mj1_v3_exp = get_irs_whole_exp(locs_initial5_Mk200_Mj1_v3_exp)
irs_initial5_Mk300_Mj1_exp = get_irs_whole_exp(locs_initial5_Mk300_Mj1_exp)
irs_initial5_Mk50_Mj1_v2_exp = get_irs_whole_exp(locs_initial5_Mk50_Mj1_v2_exp)
irs_initial5_Mk100_Mj1_exp = get_irs_whole_exp(locs_initial5_Mk100_Mj1_exp)
irs_initial5_Mk10_Mj1_exp = get_irs_whole_exp(locs_initial5_Mk10_Mj1_exp)
irs_initial5_Mk10_Mj1_v2_exp = get_irs_whole_exp(locs_initial5_Mk10_Mj1_v2_exp)
irs_initial5_Mk50_Mj1_exp = get_irs_whole_exp(locs_initial5_Mk50_Mj1_exp)
irs_initial5_Mk200_Mj1_saa_exp = get_irs_whole_exp(locs_initial5_Mk200_Mj1_saa_exp)
irs_initial5_Mk200_Mj1_saa_5seq_exp = get_irs_whole_exp(locs_initial5_Mk200_Mj1_saa_5seq_exp)
irs_initial5_Mk200_Mj1_saa_5seq_10N_exp = get_irs_whole_exp(locs_initial5_Mk200_Mj1_saa_5seq_10N_exp)

irs_saa_test_v2_exp = get_irs_whole_exp(locs_saa_test_v2_exp)
irs_saa_test_v3_exp = get_irs_whole_exp(locs_saa_test_v3_exp)

irs_saa_N5_seq5_exp = get_irs_whole_exp(locs_saa_N5_seq5_exp)

irs_saa_origin_exp = get_irs_whole_exp(locs_saa_origin_exp)

irs_saa_cumulative_exp = get_irs_whole_exp(locs_saa_cumulative_exp)
irs_saa_cumulative_exp_2 = get_irs_whole_exp(locs_saa_cumulative_exp_2)
irs_saa_cumulative_exp_3 = get_irs_whole_exp(locs_saa_cumulative_exp_3)
irs_saa_cumulative_exp_4 = get_irs_whole_exp(locs_saa_cumulative_exp_4)

irs_saa_cumulative_multi_exp = get_irs_whole_exp(locs_saa_cumulative_multi_exp)

irs_multi_start_20_exp = get_irs_whole_exp(locs_multi_start_20_exp)
irs_vanilla_toler_minus_5_exp = get_irs_whole_exp(locs_vanilla_toler_minus_5_exp)

# %% [markdown]
# #### get averaged and median value of IR

# %%
irs_Mk200_Mj_avg = get_avg_irs(irs_Mk200_Mj1_exp)
irs_Mk10_Mj_avg = get_avg_irs(irs_Mk10_Mj1_exp)

irs_initial5_Mk200_Mj1_avg = get_avg_irs(irs_initial5_Mk200_Mj1_exp)
irs_initial5_Mk200_Mj1_v2_avg = get_avg_irs(irs_initial5_Mk200_Mj1_v2_exp)
irs_initial5_Mk200_Mj1_v3_avg = get_avg_irs(irs_initial5_Mk200_Mj1_v3_exp)
irs_initial5_Mk300_Mj1_avg = get_avg_irs(irs_initial5_Mk300_Mj1_exp)
irs_initial5_Mk50_Mj1_v2_avg = get_avg_irs(irs_initial5_Mk50_Mj1_v2_exp)
irs_initial5_Mk100_Mj1_avg = get_avg_irs(irs_initial5_Mk100_Mj1_exp)
irs_initial5_Mk10_Mj1_avg = get_avg_irs(irs_initial5_Mk10_Mj1_exp)
irs_initial5_Mk10_Mj1_v2_avg = get_avg_irs(irs_initial5_Mk10_Mj1_v2_exp)
irs_initial5_Mk50_Mj1_avg = get_avg_irs(irs_initial5_Mk50_Mj1_exp)
irs_initial5_Mk5_Mj1_saa_avg = get_avg_irs(irs_initial5_Mk200_Mj1_saa_exp)
irs_initial5_Mk5_Mj1_saa_5seq_avg = get_avg_irs(irs_initial5_Mk200_Mj1_saa_5seq_exp)
irs_initial5_Mk5_Mj1_saa_5seq_10N_avg = get_avg_irs(irs_initial5_Mk200_Mj1_saa_5seq_10N_exp)

irs_saa_test_v2_avg = get_avg_irs(irs_saa_test_v2_exp)
irs_saa_test_v3_avg = get_avg_irs(irs_saa_test_v3_exp)

irs_saa_N5_seq5_avg = get_avg_irs(irs_saa_N5_seq5_exp)

irs_saa_origin_avg = get_avg_irs(irs_saa_origin_exp)

irs_saa_cumulative_avg = get_avg_irs(irs_saa_cumulative_exp)
irs_saa_cumulative_avg_2 = get_avg_irs(irs_saa_cumulative_exp_2)
irs_saa_cumulative_avg_3 = get_avg_irs(irs_saa_cumulative_exp_3)
irs_saa_cumulative_avg_4 = get_avg_irs(irs_saa_cumulative_exp_4)

irs_saa_cumulative_multi_avg = get_avg_irs(irs_saa_cumulative_multi_exp)

irs_multi_start_20_avg = get_avg_irs(irs_multi_start_20_exp)
irs_vanilla_toler_minus_5_avg = get_avg_irs(irs_vanilla_toler_minus_5_exp)

# %%
irs_Mk200_Mj_median = get_median_irs(irs_Mk200_Mj1_exp)
irs_Mk10_Mj_median = get_median_irs(irs_Mk10_Mj1_exp)

irs_initial5_Mk200_Mj1_median = get_median_irs(irs_initial5_Mk200_Mj1_exp)
irs_initial5_Mk200_Mj1_v2_median = get_median_irs(irs_initial5_Mk200_Mj1_v2_exp)
irs_initial5_Mk200_Mj1_v3_median = get_median_irs(irs_initial5_Mk200_Mj1_v3_exp)
irs_initial5_Mk300_Mj1_median = get_median_irs(irs_initial5_Mk300_Mj1_exp)
irs_initial5_Mk50_Mj1_v2_median = get_median_irs(irs_initial5_Mk50_Mj1_v2_exp)
irs_initial5_Mk100_Mj1_median = get_median_irs(irs_initial5_Mk100_Mj1_exp)
irs_initial5_Mk10_Mj1_median = get_median_irs(irs_initial5_Mk10_Mj1_exp)
irs_initial5_Mk10_Mj1_v2_median = get_median_irs(irs_initial5_Mk10_Mj1_v2_exp)
irs_initial5_Mk50_Mj1_median = get_median_irs(irs_initial5_Mk50_Mj1_exp)
irs_initial5_Mk5_Mj1_saa_median = get_median_irs(irs_initial5_Mk200_Mj1_saa_exp)
irs_initial5_Mk5_Mj1_saa_5seq_median = get_median_irs(irs_initial5_Mk200_Mj1_saa_5seq_exp)
irs_initial5_Mk5_Mj1_saa_5seq_10N_median = get_median_irs(irs_initial5_Mk200_Mj1_saa_5seq_10N_exp)

irs_saa_test_v2_median = get_median_irs(irs_saa_test_v2_exp)
irs_saa_test_v3_median = get_median_irs(irs_saa_test_v3_exp)

irs_saa_N5_seq5_median = get_median_irs(irs_saa_N5_seq5_exp)

irs_saa_origin_median = get_median_irs(irs_saa_origin_exp)

irs_saa_cumulative_median = get_median_irs(irs_saa_cumulative_exp)
irs_saa_cumulative_median_2 = get_median_irs(irs_saa_cumulative_exp_2)
irs_saa_cumulative_median_3 = get_median_irs(irs_saa_cumulative_exp_3)
irs_saa_cumulative_median_4 = get_median_irs(irs_saa_cumulative_exp_4)

irs_saa_cumulative_multi_median = get_median_irs(irs_saa_cumulative_multi_exp)

irs_multi_start_20_median = get_median_irs(irs_multi_start_20_exp)
irs_vanilla_toler_minus_5_median = get_median_irs(irs_vanilla_toler_minus_5_exp)

# %% [markdown]
# ### Plotting the real function value at suggested location

# %% [markdown]
# #### fixed Mk level, plotting real function value at suggested locations

# %%
plt.figure(figsize=(10,7))
plt.plot(avg_sugg_obj_initial5_Mk10_Mj1_v2[3:], label="Mk10, 5 initial")
plt.plot(avg_sugg_obj_initial5_Mk50_Mj1_v2[3:], label="Mk50, 5 initial")

plt.plot(avg_sugg_obj_initial5_Mk200_Mj1_v3[3:], label="Mk200, 5 initial")
#plt.plot(avg_sugg_obj_initial5_Mk300_Mj1[3:], label="Mk300, 5 initial")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,7))
#plt.plot(avg_sugg_obj_Mk200_Mj1[:], label="Mk200, Mj=1, No initial")
#plt.plot(avg_sugg_obj_Mk10_Mj1[:], label="Mk10, Mj=1, No initial")
#plt.plot(avg_sugg_obj_initial5_Mk10_Mj1[:], label="Mk10, Mj1, 5 initial")
#plt.plot(avg_sugg_obj_initial5_Mk50_Mj1[4:], label="Mk50, Mj1, 5 initial")
plt.plot(avg_sugg_obj_initial5_Mk100_Mj1[4:], label="Mk100, 5 initial")
plt.plot(avg_sugg_obj_initial5_Mk200_Mj1[4:], label="Mk200, 5 initial")

plt.plot(avg_sugg_obj_initial5_Mk50_Mj1_v2[3:], label="Mk50, 5 initial, ver2")

plt.plot(avg_sugg_obj_initial5_Mk200_Mj1_saa[3:], label="Mk5, SAA with 5 initial, 3seq")
plt.plot(avg_sugg_obj_initial5_Mk200_Mj1_saa_5seq[3:], label="Mk5, SAA with 5 initial, 5seq")
#plt.plot(avg_sugg_obj_initial5_Mk200_Mj1_saa_5seq_10N[:], label="Mk5, Mj=1, SAA with 5 random initial, 5seq, 10 incremental sample")

#plt.plot(avg_sugg_obj_saa_test[:], label="Mk5, Mj1, Mk50 limit SAA")
#plt.plot(avg_sugg_obj_saa_v2_test[4:], label="Mk5, Mj1, Mk50 limit SAA ver2")
#plt.plot(avg_sugg_obj_saa_v3_test[3:], label="Mk5, Mj1, Mk50 limit SAA ver2")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,7))
#plt.plot(avg_sugg_obj_initial5_Mk10_Mj1_v2[3:], label="Mk10, 5 initial")
#plt.plot(avg_sugg_obj_initial5_Mk50_Mj1_v2[3:], label="Mk50, 5 initial")
plt.plot(avg_sugg_obj_initial5_Mk200_Mj1_v3[3:], label="Mk200, 5 initial")
#plt.plot(avg_sugg_obj_saa_N5_seq5[3:],label="heuristic SAA")
#plt.plot(avg_sugg_obj_saa_origin[3:], label="original SAA")
plt.plot(avg_sugg_obj_saa_cumulative[3:], label="cumulative SAA")
plt.plot(avg_sugg_obj_saa_cumulative_2[3:], label="cumulative SAA_v2")
plt.plot(avg_sugg_obj_saa_cumulative_3[3:], label="cumulative SAA_v3")
plt.plot(avg_sugg_obj_saa_cumulative_4[3:], label="cumulative SAA_v4")
plt.ylim(ymin=0, ymax=6)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,7))
#plt.plot(irs_Mk200_Mj_avg, label='Mk200, Mj1, No initial')
#plt.plot(irs_Mk10_Mj_avg, label='Mk10, Mj1, No initial')
#plt.plot(irs_initial5_Mk10_Mj1_avg, label='Mk10, Mj1, 5 initial')
plt.plot(irs_initial5_Mk50_Mj1_avg, label='Mk50, 5 initial')
plt.plot(irs_initial5_Mk100_Mj1_avg, label='Mk100, 5 initial')
plt.plot(irs_initial5_Mk200_Mj1_avg, label='Mk200, 5 initial')
plt.plot(irs_initial5_Mk200_Mj1_v2_avg, label='Mk200, 5 initial, ver2')
plt.plot(irs_initial5_Mk5_Mj1_saa_avg, label='Mk5, SAA with 5 random initial')
plt.plot(irs_initial5_Mk5_Mj1_saa_5seq_avg, label='Mk5, SAA with 5 random initial, 5seq')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,7))
#plt.plot(irs_Mk200_Mj_avg, label='Mk200, Mj1, No initial')
#plt.plot(irs_Mk10_Mj_avg, label='Mk10, Mj1, No initial')
plt.plot(irs_initial5_Mk10_Mj1_v2_avg[3:], label='Mk10, Mj1, 5 initial')
plt.plot(irs_initial5_Mk50_Mj1_v2_avg[3:], label='Mk50, 5 initial')
#plt.plot(irs_initial5_Mk100_Mj1_avg, label='Mk100, 5 initial')
#plt.plot(irs_initial5_Mk200_Mj1_avg, label='Mk200, 5 initial')
plt.plot(irs_initial5_Mk200_Mj1_v3_avg[3:], label='Mk200, 5 initial, ver2')
#plt.plot(irs_initial5_Mk5_Mj1_saa_avg, label='Mk5, SAA with 5 random initial')
#plt.plot(irs_initial5_Mk5_Mj1_saa_5seq_avg, label='Mk5, SAA with 5 random initial, 5seq')
plt.plot(irs_saa_test_v3_avg[3:], label='SAA ver3')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,7))
#plt.plot(avg_sugg_obj_Mk200_Mj1[:], label="Mk200, Mj=1, No initial")
#plt.plot(avg_sugg_obj_Mk10_Mj1[:], label="Mk10, Mj=1, No initial")
#plt.plot(avg_sugg_obj_initial5_Mk10_Mj1[:], label="Mk10, Mj1, 5 initial")
plt.plot(avg_sugg_obj_initial5_Mk10_Mj1_v2[3:], label="Mk10, 5 initial")
plt.plot(avg_sugg_obj_initial5_Mk50_Mj1_v2[3:], label="Mk50, 5 initial")
#plt.plot(avg_sugg_obj_initial5_Mk50_Mj1[4:], label="Mk50, Mj1, 5 initial")
#plt.plot(avg_sugg_obj_initial5_Mk100_Mj1[4:], label="Mk100, Mj1, 5 initial")
plt.plot(avg_sugg_obj_initial5_Mk200_Mj1_v3[3:], label="Mk200, 5 initial")



#plt.plot(avg_sugg_obj_initial5_Mk200_Mj1_saa[3:], label="Mk5, Mj=1, SAA with 5 random initial")
#plt.plot(avg_sugg_obj_initial5_Mk200_Mj1_saa_5seq[:], label="Mk5, Mj=1, SAA with 5 random initial, 5seq")
#plt.plot(avg_sugg_obj_initial5_Mk200_Mj1_saa_5seq_10N[:], label="Mk5, Mj=1, SAA with 5 random initial, 5seq, 10 incremental sample")

#plt.plot(avg_sugg_obj_saa_test[:], label="Mk5, Mj1, Mk50 limit SAA")
#plt.plot(avg_sugg_obj_saa_v3_test[3:], label="Mk5, Mk50 limit SAA ver3")
#plt.plot(avg_sugg_obj_saa_N5_seq5[3:], label="SAA 5 incre N, 5 seq")
plt.legend()
plt.show()

# %% [markdown]
# ### Mk50 Multistart vs Mk50 single start vs Mk200 single start

# %%
plt.figure(figsize=(10,7))

plt.plot(avg_sugg_obj_initial5_Mk200_Mj1_v3[3:], label="Mk200, 5 initial")

plt.plot(avg_sugg_obj_initial5_Mk50_Mj1_v2[3:], label="Mk50, 5 initial")
#plt.plot(avg_sugg_obj_vanilla_toler_minus_5[3:], label="Mk50, opt tolerance 1e-5")

plt.plot(avg_sugg_obj_multi_start_20[3:], label="multistart, Mk50, 5 initial")
plt.plot(avg_sugg_obj_saa_cumulative_multi[3:], label="SAA with multistart")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,7))
#plt.plot(irs_initial5_Mk10_Mj1_v2_avg[3:], label="Mk10, 5 initial")
#plt.plot(irs_initial5_Mk50_Mj1_v2_avg[3:], label='Mk50, 5 initial')

plt.plot(irs_initial5_Mk200_Mj1_v3_avg[3:], label='Mk200, 5 initial')
#plt.plot(irs_saa_N5_seq5_avg[3:], label='heuristic SAA')
#plt.plot(irs_saa_origin_avg[3:], label='original SAA')

plt.plot(irs_saa_cumulative_avg[3:], label='cumulative SAA')
plt.plot(irs_saa_cumulative_avg_2[3:], label='cumulative SAA_v2')
plt.plot(irs_saa_cumulative_avg_3[3:], label='cumulative SAA_v3')
plt.plot(irs_saa_cumulative_avg_4[3:], label='cumulative SAA_v4')


plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,7))
#plt.plot(irs_initial5_Mk10_Mj1_v2_avg[3:], label="Mk10, 5 initial")
#plt.plot(irs_initial5_Mk50_Mj1_v2_avg[3:], label='Mk50, 5 initial')

plt.plot(irs_initial5_Mk200_Mj1_v3_avg[3:], label='Mk200, 5 initial')
#plt.plot(irs_saa_N5_seq5_avg[3:], label='heuristic SAA')
#plt.plot(irs_saa_origin_avg[3:], label='original SAA')

plt.plot(irs_saa_cumulative_avg[3:], label='cumulative SAA')
plt.plot(irs_saa_cumulative_avg_2[3:], label='cumulative SAA_v2')
plt.plot(irs_saa_cumulative_avg_3[3:], label='cumulative SAA_v3')
plt.plot(irs_saa_cumulative_avg_4[3:], label='cumulative SAA_v4')


plt.legend()
plt.show()

# %% [markdown]
# ### avg irs: Mk50 multistart vs Mk50 single start vs Mk200 single start

# %%
plt.figure(figsize=(10,7))



plt.plot(irs_initial5_Mk200_Mj1_v3_avg[3:], label='Mk200, 5 initial')
plt.plot(irs_initial5_Mk50_Mj1_v2_avg[3:], label='Mk50, 5 initial')
plt.plot(irs_vanilla_toler_minus_5_avg[3:], label="Mk50, opt tolerance 1e-5")
plt.plot(irs_multi_start_20_avg[3:], label="multistart, Mk50 5 initial")

plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,7))
#plt.plot(irs_initial5_Mk10_Mj1_v2_median[3:], label="Mk10, 5 initial")
#plt.plot(irs_initial5_Mk50_Mj1_v2_median[3:], label='Mk50, 5 initial')

plt.plot(irs_initial5_Mk200_Mj1_v3_median[3:], label='Mk200, 5 initial')
plt.plot(irs_saa_N5_seq5_median[3:], label='heuristic SAA')

#plt.plot(irs_saa_origin_median[3:], label='original SAA')

plt.plot(irs_saa_cumulative_median[3:], label='cumulative SAA')
plt.plot(irs_saa_cumulative_median_2[3:], label='cumulative SAA_v2')


plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,7))
#plt.plot(irs_initial5_Mk10_Mj1_v2_avg[3:], label="Mk10, 5 initial")
#plt.plot(irs_initial5_Mk50_Mj1_v2_avg[3:], label='Mk50, 5 initial')

plt.plot(irs_initial5_Mk200_Mj1_v3_avg[3:], label='Mk200, 5 initial')
plt.plot(irs_saa_N5_seq5_avg[3:], label='heuristic SAA')


plt.legend()
plt.show()

# %% [markdown]
# ### irs avg : Mk50 multistart vs Mk50 single start vs Mk200 single start

# %%
plt.figure(figsize=(10,7))


plt.plot(irs_initial5_Mk200_Mj1_v3_median[3:], label='Mk200, 5 initial')
plt.plot(irs_initial5_Mk50_Mj1_v2_median[3:], label='Mk50, 5 initial')
plt.plot(irs_vanilla_toler_minus_5_median[3:], label='Mk50, opt tolearance 1e-5')


plt.plot(irs_multi_start_20_median[3:], label="multistart, Mk50 5 initial")

plt.legend()
plt.show()
